# %%
# %run nbaanalysis.py
# Out:
# Run "%matplotlib inline" for graphs
# nbaanalysis.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   t['W-L'][n] = str(t['W'][n]) + '-' + str(t['L'][n])
# /Users/royh21k/anaconda/lib/python2.7/site-packages/scipy/stats/stats.py:250: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
# %matplotlib inline

# %%
twinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.996929
# +/-   0.954684
# FG%   0.670365
# 3P%   0.596784
# PTS   0.557082
# AST   0.486139
# FGM   0.483056
# STL   0.405989
# 3PM   0.379441
# BLK   0.221023
# PFD   0.218665
# 3PA   0.213599
# DREB  0.211531
# FTM   0.182089
# FTA   0.173158
# FT%   0.119703
# REB   0.063051
# MIN  -0.017754
# GP   -0.097551
# OREB -0.117452
# FGA  -0.124087
# TOV  -0.237991
# PF   -0.277099
# BLKA -0.501282
# L    -0.997933

# %%
plotTeamsWinper("BLKA")

# %%
pwinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.491680
# +/-   0.482261
# AGE   0.123314
# AST   0.050738
# STL   0.050198
# 3PM   0.046483
# TD3   0.041747
# GP    0.041544
# DD2   0.025867
# 3PA   0.024952
# BLK   0.023799
# FG%   0.013422
# PTS   0.012380
# FTM   0.007194
# FGM   0.005633
# TOV  -0.001690
# FTA  -0.002276
# FT%  -0.003431
# DREB -0.004879
# 3P%  -0.005430
# REB  -0.016182
# FGA  -0.019671
# MIN  -0.026612
# OREB -0.036755
# PF   -0.039751
# L    -0.458328

# %%
plotPlayersWinper("+/-")

# %%
plotTeamWFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6      3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025
# 13     AST   0.429617   0.429617  0.000007   0.509294   0.509294  0.000115
# 1      FGM   0.374500   0.374500  0.000089   0.444920   0.444920  0.000950

# %%
plotTeamLFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 9      FT%   0.232321   0.232321  0.015061   0.280642   0.280642  0.043879
# 12     REB   0.194280   0.194280  0.042066   0.231289   0.231289  0.098992
# 16     TOV  -0.320719   0.320719  0.000791  -0.374924   0.374924  0.006171

# %%
plotTeamWFactBox("GSW")
# Out:
# GSW
# RECORD: 44-8
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6     3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025

# %%
plotTeamLFactBox("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 16     TOV  -0.320719   0.320719  0.000791  -0.374924   0.374924  0.006171

# %%
plotTeamHomeFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#   STATVAR  ARENAktcorr  absktcorr    ktpval  ARENAsmcorr  abssmcorr    smpval
# 6     3P%     0.352397   0.352397  0.000227     0.425541   0.425541  0.001661
# 1     FGM     0.341583   0.341583  0.000351     0.405814   0.405814  0.002837
# 3     FG%     0.306755   0.306755  0.001328     0.370426   0.370426  0.006869

# %%
print rosterOrderbyImpact("GSW")
print rosterOrderbyPosImpact("GSW")
print rosterOrderbyNegImpact("GSW")
print rosterOrderbyHomeImpact("GSW")
print rosterOrderbyAwayImpact("GSW")
# Out:
# ['Klay Thompson', 'Draymond Green', 'Stephen Curry', 'Andre Iguodala', 'Kevin Durant', 'Shaun Livingston', 'Ian Clark', 'Zaza Pachulia', 'JaVale McGee', 'David West', 'Patrick McCaw', 'Kevon Looney', 'Anderson Varejao', 'James Michael McAdoo', 'Briante Weber', 'Damian Jones']
# ['Klay Thompson', 'Kevin Durant', 'Andre Iguodala', 'Draymond Green', 'Stephen Curry', 'Zaza Pachulia', 'JaVale McGee', 'Ian Clark', 'Shaun Livingston', 'Patrick McCaw', 'David West', 'Kevon Looney', 'James Michael McAdoo', 'Anderson Varejao', 'Briante Weber', 'Damian Jones']
# ['Draymond Green', 'Stephen Curry', 'Shaun Livingston', 'Andre Iguodala', 'David West', 'Ian Clark', 'Anderson Varejao', 'Kevin Durant', 'Klay Thompson', 'JaVale McGee', 'Zaza Pachulia', 'Patrick McCaw', 'Kevon Looney', 'James Michael McAdoo', 'Briante Weber', 'Damian Jones']
# ['Klay Thompson', 'Kevin Durant', 'Ian Clark', 'Shaun Livingston', 'Stephen Curry', 'Draymond Green', 'Kevon Looney', 'JaVale McGee', 'Anderson Varejao', 'Patrick McCaw', 'James Michael McAdoo', 'Damian Jones', 'Andre Iguodala', 'Zaza Pachulia', 'David West', 'Briante Weber']
# ['Ian Clark', 'JaVale McGee', 'Briante Weber', 'Damian Jones', 'Anderson Varejao', 'Kevon Looney', 'Patrick McCaw', 'David West', 'Klay Thompson', 'James Michael McAdoo', 'Zaza Pachulia', 'Draymond Green', 'Shaun Livingston', 'Stephen Curry', 'Kevin Durant', 'Andre Iguodala']

# %%
plotPlayerWFactors("Klay Thompson")
# Out:
# Klay Thompson
#    STATVAR  W/Lktcorr  absktcorr        ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.490760   0.490760  2.132024e-07   0.589617   0.589617  0.000003
# 3      FG%   0.289008   0.289008  2.251485e-03   0.348169   0.348169  0.010626
# 6      3P%   0.262071   0.262071  5.602998e-03   0.312453   0.312453  0.022738

# %%
plotPlayerLFactors("Draymond Green")
# Out:
# Draymond Green
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 0      PTS  -0.258421   0.258421  0.007447  -0.306595   0.306595  0.028652
# 16     TOV  -0.272254   0.272254  0.004811  -0.305562   0.305562  0.029221
# 1      FGM  -0.293177   0.293177  0.002397  -0.335579   0.335579  0.016068

# %%
plotPlayerHomeFactors("Klay Thompson")
# Out:
# Klay Thompson
#   STATVAR  ARENAktcorr  absktcorr    ktpval  ARENAsmcorr  abssmcorr    smpval
# 3     FG%     0.334487   0.334487  0.000407     0.402957   0.402957  0.002775
# 6     3P%     0.294891   0.294891  0.001827     0.351582   0.351582  0.009837
# 4     3PM     0.193203   0.193203  0.041131     0.221289   0.221289  0.111293

# %%
plotPlayerWFactBox("Klay Thompson")
# Out:
# Klay Thompson
#    STATVAR  W/Lktcorr  absktcorr        ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-    0.49076    0.49076  2.132024e-07   0.589617   0.589617  0.000003

# %%
plotPlayerLFactBox("Draymond Green")
# Out:
# Draymond Green
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 1     FGM  -0.293177   0.293177  0.002397  -0.335579   0.335579  0.016068
