# %%
# %run nbaanalysis.py
# Out:
# Run '%matplotlib inline' for graphs
# Functions:
#   getPlayerStats(player)
#   getPlayerDefStats(player)
#   getPlayerGamelogs(player)
# nbaanalysis.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   t['W-L'][n] = str(t['W'][n]) + '-' + str(t['L'][n])
#   getTeamStats(team)
#   getTeamGamelogs(team)
# Plot against Win%:
#   plotPlayersWinper(var)
#   plotTeamsWinper(var)
# /Users/royh21k/anaconda/lib/python2.7/site-packages/scipy/stats/stats.py:250: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Plot functions:
#   plotPlayerWFactors(player)
#   plotPlayerLFactors(player)
#   plotPlayerHomeFactors(player)
#   plotPlayerWFactBox(player)
#   plotPlayerLFactBox(player)
# ...

# %%
# %matplotlib inline

# %%
twinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.996929
# +/-   0.954684
# FG%   0.670365
# 3P%   0.596784
# PTS   0.557082
# AST   0.486139
# FGM   0.483056
# STL   0.405989
# 3PM   0.379441
# BLK   0.221023
# PFD   0.218665
# 3PA   0.213599
# DREB  0.211531
# FTM   0.182089
# FTA   0.173158
# FT%   0.119703
# REB   0.063051
# MIN  -0.017754
# GP   -0.097551
# OREB -0.117452
# FGA  -0.124087
# TOV  -0.237991
# PF   -0.277099
# BLKA -0.501282
# L    -0.997933

# %%
plotTeamsWinper("BLKA")

# %%
pwinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.491680
# +/-   0.482261
# AGE   0.123314
# AST   0.050738
# STL   0.050198
# 3PM   0.046483
# TD3   0.041747
# GP    0.041544
# DD2   0.025867
# 3PA   0.024952
# BLK   0.023799
# FG%   0.013422
# PTS   0.012380
# FTM   0.007194
# FGM   0.005633
# TOV  -0.001690
# FTA  -0.002276
# FT%  -0.003431
# DREB -0.004879
# 3P%  -0.005430
# REB  -0.016182
# FGA  -0.019671
# MIN  -0.026612
# OREB -0.036755
# PF   -0.039751
# L    -0.458328

# %%
plotPlayersWinper("+/-")

# %%
plotTeamWFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6      3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025
# 13     AST   0.429617   0.429617  0.000007   0.509294   0.509294  0.000115
# 1      FGM   0.374500   0.374500  0.000089   0.444920   0.444920  0.000950

# %%
plotTeamLFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 8      FTA  -0.110158   0.110158  0.249056  -0.131609   0.131609  0.352356
# 17      PF  -0.127093   0.127093  0.183569  -0.149711   0.149711  0.289451
# 16     TOV  -0.320719   0.320719  0.000791  -0.374924   0.374924  0.006171

# %%
plotTeamWFactBox("GSW")
# Out:
# GSW
# RECORD: 44-8
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6     3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025

# %%
plotTeamLFactBox("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 16     TOV  -0.320719   0.320719  0.000791  -0.374924   0.374924  0.006171

# %%
plotTeamHomeFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6      3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025
# 13     AST   0.429617   0.429617  0.000007   0.509294   0.509294  0.000115
# 1      FGM   0.374500   0.374500  0.000089   0.444920   0.444920  0.000950

# %%
plotTeamWFactors("BKN")
# Out:
# BKN
# RECORD: 9-44
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 0      PTS   0.398701   0.398701  0.000025   0.477057   0.477057  0.000304
# 7      FTM   0.352615   0.352615  0.000194   0.417018   0.417018  0.001894
# 11    DREB   0.350683   0.350683  0.000210   0.415252   0.415252  0.001989

# %%
plotTeamLFactors("BKN")
# Out:
# BKN
# RECORD: 9-44
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 16     TOV  -0.037224   0.037224  0.693977  -0.043141   0.043141  0.759052
# 10    OREB  -0.060971   0.060971  0.519263  -0.071118   0.071118  0.612826
# 2      FGA  -0.167997   0.167997  0.075771  -0.199334   0.199334  0.152437

# %%
plotTeamWFactBox("BKN")
# Out:
# BKN
# RECORD: 9-44
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 0     PTS   0.398701   0.398701  0.000025   0.477057   0.477057  0.000304

# %%
plotTeamLFactBox("BKN")
# Out:
# BKN
# RECORD: 9-44
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 2     FGA  -0.167997   0.167997  0.075771  -0.199334   0.199334  0.152437

# %%
plotTeamHomeFactors("BKN")
# Out:
# BKN
# RECORD: 9-44
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 0      PTS   0.398701   0.398701  0.000025   0.477057   0.477057  0.000304
# 7      FTM   0.352615   0.352615  0.000194   0.417018   0.417018  0.001894
# 11    DREB   0.350683   0.350683  0.000210   0.415252   0.415252  0.001989

# %%
teamlist["GSW"]["PLAYERS"]
# Out:
# ['Kevin Durant',
#  'Stephen Curry',
#  'Klay Thompson',
#  'Draymond Green',
#  'Ian Clark',
#  'Andre Iguodala',
#  'JaVale McGee',
#  'Zaza Pachulia',
#  'Shaun Livingston',
#  'David West',
#  'Patrick McCaw',
#  'Kevon Looney',
#  'James Michael McAdoo',
#  'Briante Weber',
#  'Damian Jones',
#  'Anderson Varejao']

# %%
plotPlayerWFactors("Kevin Durant")
# Out:
# Kevin Durant
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.427277   0.427277  0.000005   0.515308   0.515308  0.000067
# 13     AST   0.347689   0.347689  0.000206   0.402937   0.402937  0.002520
# 6      3P%   0.188029   0.188029  0.044711   0.220528   0.220528  0.109063

# %%
plotPlayerLFactors("Kevin Durant")
# Out:
# Kevin Durant
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 8      FTA  -0.144531   0.144531  0.122833  -0.169685   0.169685  0.219948
# 11    DREB  -0.169113   0.169113  0.071008  -0.198272   0.198272  0.150656
# 5      3PA  -0.179879   0.179879  0.054812  -0.206424   0.206424  0.134240

# %%
plotPlayerWFactBox("Kevin Durant")
# Out:
# Kevin Durant
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.427277   0.427277  0.000005   0.515308   0.515308  0.000067

# %%
plotPlayerLFactBox("Kevin Durant")
# Out:
# Kevin Durant
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr   smpval
# 5     3PA  -0.179879   0.179879  0.054812  -0.206424   0.206424  0.13424

# %%
plotPlayerHomeFactors("Kevin Durant")
# Out:
# Kevin Durant
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.427277   0.427277  0.000005   0.515308   0.515308  0.000067
# 13     AST   0.347689   0.347689  0.000206   0.402937   0.402937  0.002520
# 6      3P%   0.188029   0.188029  0.044711   0.220528   0.220528  0.109063

# %%
teamlist["BKN"]["PLAYERS"]
# Out:
# ['Brook Lopez',
#  'Bojan Bogdanovic',
#  'Jeremy Lin',
#  'Sean Kilpatrick',
#  'Trevor Booker',
#  'Joe Harris',
#  'Rondae Hollis-Jefferson',
#  'Caris LeVert',
#  'Isaiah Whitehead',
#  'Justin Hamilton',
#  'Spencer Dinwiddie',
#  'Luis Scola',
#  'Randy Foye',
#  'Quincy Acy',
#  'Anthony Bennett',
#  'Chris McCullough',
#  'Greivis Vasquez']

# %%
plotPlayerWFactors("Brook Lopez")
# Out:
# Brook Lopez
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.445082   0.445082  0.000006   0.535107   0.535107  0.000075
# 12     REB   0.231073   0.231073  0.019162   0.267010   0.267010  0.063646
# 0      PTS   0.195108   0.195108  0.047952   0.231747   0.231747  0.109100

# %%
plotPlayerLFactors("Brook Lopez")
# Out:
# Brook Lopez
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 13     AST   0.030258   0.030258  0.759052   0.034213   0.034213  0.815471
# 6      3P%   0.024351   0.024351  0.805027   0.028246   0.028246  0.847230
# 17      PF  -0.188076   0.188076  0.056583  -0.209509   0.209509  0.148517

# %%
plotPlayerWFactBox("Brook Lopez")
# Out:
# Brook Lopez
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.445082   0.445082  0.000006   0.535107   0.535107  0.000075

# %%
plotPlayerLFactBox("Brook Lopez")
# Out:
# Brook Lopez
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 17      PF  -0.188076   0.188076  0.056583  -0.209509   0.209509  0.148517

# %%
plotPlayerHomeFactors("Brook Lopez")
# Out:
# Brook Lopez
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.445082   0.445082  0.000006   0.535107   0.535107  0.000075
# 12     REB   0.231073   0.231073  0.019162   0.267010   0.267010  0.063646
# 0      PTS   0.195108   0.195108  0.047952   0.231747   0.231747  0.109100
