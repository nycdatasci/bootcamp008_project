# %%
# %run nbaanalysis.py
# Out:
# Run "%matplotlib inline" for graphs
# Functions:
#   getPlayerStats(player)
#   getPlayerDefStats(player)
#   getPlayerGamelogs(player)
# nbaanalysis.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   t['W-L'][n] = str(t['W'][n]) + '-' + str(t['L'][n])
#   getTeamStats(team)
#   getTeamGamelogs(team)
# Plot against Win%:
#   plotPlayersWinper(var)
#   plotTeamsWinper(var)
# /Users/royh21k/anaconda/lib/python2.7/site-packages/scipy/stats/stats.py:250: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Plot functions:
#   plotPlayerWFactors(player)
#   plotPlayerLFactors(player)
#   plotPlayerHomeFactors(player)
#   plotPlayerWFactBox(player)
#   plotPlayerLFactBox(player)
#   plotTeamWFactors(team)
#   plotTeamLFactors(team)
#   plotTeamHomeFactors(team)
#   plotTeamWFactBox(team)
#   plotTeamLFactBox(team)

# %%
# %matplotlib inline

# %%
twinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.996929
# +/-   0.954684
# FG%   0.670365
# 3P%   0.596784
# PTS   0.557082
# AST   0.486139
# FGM   0.483056
# STL   0.405989
# 3PM   0.379441
# BLK   0.221023
# PFD   0.218665
# 3PA   0.213599
# DREB  0.211531
# FTM   0.182089
# FTA   0.173158
# FT%   0.119703
# REB   0.063051
# MIN  -0.017754
# GP   -0.097551
# OREB -0.117452
# FGA  -0.124087
# TOV  -0.237991
# PF   -0.277099
# BLKA -0.501282
# L    -0.997933

# %%
plotTeamsWinper("BLKA")

# %%
pwinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.491680
# +/-   0.482261
# AGE   0.123314
# AST   0.050738
# STL   0.050198
# 3PM   0.046483
# TD3   0.041747
# GP    0.041544
# DD2   0.025867
# 3PA   0.024952
# BLK   0.023799
# FG%   0.013422
# PTS   0.012380
# FTM   0.007194
# FGM   0.005633
# TOV  -0.001690
# FTA  -0.002276
# FT%  -0.003431
# DREB -0.004879
# 3P%  -0.005430
# REB  -0.016182
# FGA  -0.019671
# MIN  -0.026612
# OREB -0.036755
# PF   -0.039751
# L    -0.458328

# %%
plotPlayersWinper("+/-")

# %%
plotTeamWFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6      3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025
# 13     AST   0.429617   0.429617  0.000007   0.509294   0.509294  0.000115
# 1      FGM   0.374500   0.374500  0.000089   0.444920   0.444920  0.000950

# %%
plotTeamLFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 8      FTA  -0.110158   0.110158  0.249056  -0.131609   0.131609  0.352356
# 17      PF  -0.127093   0.127093  0.183569  -0.149711   0.149711  0.289451
# 16     TOV  -0.320719   0.320719  0.000791  -0.374924   0.374924  0.006171

# %%
plotTeamWFactBox("GSW")
# Out:
# GSW
# RECORD: 44-8
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6     3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025

# %%
plotTeamLFactBox("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 16     TOV  -0.320719   0.320719  0.000791  -0.374924   0.374924  0.006171

# %%
plotTeamHomeFactors("GSW")
# Out:
# GSW
# RECORD: 44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 6      3P%   0.454522   0.454522  0.000002   0.548863   0.548863  0.000025
# 13     AST   0.429617   0.429617  0.000007   0.509294   0.509294  0.000115
# 1      FGM   0.374500   0.374500  0.000089   0.444920   0.444920  0.000950

# %%
print rosterOrderbyImpact("GSW")
print rosterOrderbyPosImpact("GSW")
print rosterOrderbyNegImpact("GSW")
print rosterOrderbyHomeImpact("GSW")
print rosterOrderbyAwayImpact("GSW")
# Out:
# ['Draymond Green', 'Stephen Curry', 'Klay Thompson', 'Kevin Durant', 'Andre Iguodala', 'Shaun Livingston', 'Ian Clark', 'Zaza Pachulia', 'David West', 'Patrick McCaw', 'JaVale McGee', 'Kevon Looney', 'James Michael McAdoo', 'Anderson Varejao', 'Damian Jones', 'Briante Weber']
# ['Klay Thompson', 'Andre Iguodala', 'Kevin Durant', 'Draymond Green', 'Stephen Curry', 'Ian Clark', 'Zaza Pachulia', 'Patrick McCaw', 'JaVale McGee', 'Kevon Looney', 'James Michael McAdoo', 'David West', 'Shaun Livingston', 'Anderson Varejao', 'Damian Jones', 'Briante Weber']
# ['Draymond Green', 'Stephen Curry', 'Kevin Durant', 'Shaun Livingston', 'Andre Iguodala', 'David West', 'Klay Thompson', 'Anderson Varejao', 'Zaza Pachulia', 'Ian Clark', 'Damian Jones', 'Kevon Looney', 'Patrick McCaw', 'James Michael McAdoo', 'JaVale McGee', 'Briante Weber']
# ['Draymond Green', 'Stephen Curry', 'Kevin Durant', 'Klay Thompson', 'Andre Iguodala', 'Ian Clark', 'Shaun Livingston', 'Zaza Pachulia', 'David West', 'Patrick McCaw', 'JaVale McGee', 'Kevon Looney', 'James Michael McAdoo', 'Anderson Varejao', 'Damian Jones', 'Briante Weber']
# ['Draymond Green', 'Stephen Curry', 'Klay Thompson', 'Kevin Durant', 'Andre Iguodala', 'Shaun Livingston', 'Ian Clark', 'Zaza Pachulia', 'Patrick McCaw', 'David West', 'JaVale McGee', 'Kevon Looney', 'James Michael McAdoo', 'Damian Jones', 'Anderson Varejao', 'Briante Weber']

# %%
plotPlayerWFactors("Klay Thompson")
# Out:
# Klay Thompson
#    STATVAR  W/Lktcorr  absktcorr        ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.490760   0.490760  2.132024e-07   0.589617   0.589617  0.000003
# 3      FG%   0.289008   0.289008  2.251485e-03   0.348169   0.348169  0.010626
# 6      3P%   0.262071   0.262071  5.602998e-03   0.312453   0.312453  0.022738

# %%
plotPlayerLFactors("Draymond Green")
# Out:
# Draymond Green
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 0      PTS  -0.258421   0.258421  0.007447  -0.306595   0.306595  0.028652
# 16     TOV  -0.272254   0.272254  0.004811  -0.305562   0.305562  0.029221
# 1      FGM  -0.293177   0.293177  0.002397  -0.335579   0.335579  0.016068

# %%
plotPlayerHomeFactors("Draymond Green")
# Out:
# Draymond Green
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-   0.430563   0.430563  0.000008   0.516948   0.516948  0.000103
# 1      FGM  -0.293177   0.293177  0.002397  -0.335579   0.335579  0.016068
# 15     BLK   0.279618   0.279618  0.003783   0.309698   0.309698  0.026998

# %%
plotPlayerWFactBox("Klay Thompson")
# Out:
# Klay Thompson
#    STATVAR  W/Lktcorr  absktcorr        ktpval  W/Lsmcorr  abssmcorr    smpval
# 18     +/-    0.49076    0.49076  2.132024e-07   0.589617   0.589617  0.000003

# %%
plotPlayerLFactBox("Draymond Green")
# Out:
# Draymond Green
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 1     FGM  -0.293177   0.293177  0.002397  -0.335579   0.335579  0.016068
