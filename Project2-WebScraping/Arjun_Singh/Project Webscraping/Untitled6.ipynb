# %%
add.shape[0]*1./8
# Out:
# 13735.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
add = pd.read_csv('recode1.csv')
add.head(100)
# Out:
#     Unnamed: 0                                                  0
# 0            0                                         Search JPL
# 1            1  Orbital Elements at Epoch 2457800.5 (2017-Feb-...
# 2            2    Reference: JPL 16 (heliocentric ecliptic J2000)
# 3            3                                             JPL 16
# 4            4                                            Element
# 5            5                                              Value
# 6            6                             Uncertainty (1-sigma)
# 7            7                                             Units
# 8            8                                                  e
# 9            9                                  .6672363551742017
# 10          10                                          4.922e-08
# 11          11
# 12          12                                                  a
# 13          13                                  2.804294334230965
# ...

# %%
#df[df['A'].str.contains("hello")]
x = np.zeros(shape=(1146,15))*np.NaN

# %%
list = ('Element','Value','Uncertainty (1-sigma)','Units', '# obs. used (total)','data-arc span','first obs. used','last obs. used','planetary ephem','SB-pert. ephem.',' condition code','fit RMS',' data source','producer','solution date')
y = pd.DataFrame(x,columns = list)

# %%
current_col=None
row_num=0
for element in add['0']:
    if element =='Search JPL':
        row_num +=1
        continue
    if element in y.columns:
        current_col =element
        continue
    y.ix[row_num , current_col] = element

# %%
new1 = (add[add['0'].str.contains("Search JPL")])
new1
new1.index
# Out:
# Int64Index([     0,     96,    190,    284,    378,    472,    566,    660,
#                754,    848,
#             ...
#             108863, 108986, 109091, 109185, 109279, 109373, 109478, 109574,
#             109682, 109790],
#            dtype='int64', length=1146)

# %%
for i in new1.index:
    for j in range(4):
        for
# Out:
# 108

# %%
aaaa = np.zeros(shape=(12,4)).astype(object)

# %%
j = 108863
aaaa = pd.DataFrame(np.zeros(shape=(12,4)).astype(object))
names = []
for i in range(51):
    if i>=4 and i<=7:
        name = add['0'].iloc[i+j]
        names.append(name)
        print names
    elif i>7:
        aaaa.iloc[(i-8)/4, (i-8)%4] = add['0'].iloc[i+j]
        
aaaa.columns = names
# Out:
# ['\xc2\xa0Element']
# ['\xc2\xa0Element', 'Value']
# ['\xc2\xa0Element', 'Value', 'Uncertainty (1-sigma)\xc2\xa0']
# ['\xc2\xa0Element', 'Value', 'Uncertainty (1-sigma)\xc2\xa0', '\xc2\xa0Units\xc2\xa0']

# %%
aaaa
# Out:
#     Element                                       Value  \
# 0         e                           .8684255181688821
# 1         a                           .9067176671855004
# 2         q                           .1193009072270522
# 3         i                           4.035236912921982
# 4      node                           342.7832822328972
# 5      peri                           322.3923467835415
# 6         M                           229.7763459662735
# 7        tp  2453597.575904344770(2005-Aug-15.07590434)
# 8    period                       315.35995414075260.86
# 9         n                           1.141552677418654
# 10        Q                           1.694134427143949
# 11        0                                           0
#
#    Uncertainty (1-sigma)   Units
# 0              1.3037e-07
# 1               2.174e-09      au
# 2              1.1804e-07      au
# 3              2.3771e-05     deg
# 4              7.5397e-05     deg
# ...

# %%
add.head(48)
# Out:
#     Unnamed: 0                                                  0
# 0            0                                         Search JPL
# 1            1  Orbital Elements at Epoch 2457800.5 (2017-Feb-...
# 2            2    Reference: JPL 16 (heliocentric ecliptic J2000)
# 3            3                                             JPL 16
# 4            4                                            Element
# 5            5                                              Value
# 6            6                             Uncertainty (1-sigma)
# 7            7                                             Units
# 8            8                                                  e
# 9            9                                  .6672363551742017
# 10          10                                          4.922e-08
# 11          11
# 12          12                                                  a
# 13          13                                  2.804294334230965
# ...
