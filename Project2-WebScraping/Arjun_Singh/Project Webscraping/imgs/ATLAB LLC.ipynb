# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import re

# %%
df =pd.read_csv("price.csv")
df1=pd.read_csv("product_id.csv")
df2 = pd.read_csv("product_name.csv")

# %%
Atlab_LLC = pd.concat([df1,df2,df,df_new],1,ignore_index=True)

# %%
Atlab_LLC.columns=['ORDER ID', 'Product Name', 'Price ( AED )','Description']

# %%
Atlab_products_all = Atlab_LLC.to_csv('Atlab_product.csv')

# %%
df_new = pd.read_csv("product_description.csv")

# %%
Atlab_LLC
# Out:
#           ORDER ID                                       Product Name  \
# 0      3DXYZCP2ADV                  3D Printer Advance Classroom pack
# 1         3DXYZCP1                          3D Printer Classroom pack
# 2            45110                            BuildToExpress Core Set
# 3          2045110               BuildToExpress Guide & Activity Pack
# 4      3FM1XXAE00K                                 da Vinci Minimaker
# 5            45120               LearnToLearn Core Set and Curriculum
# 6            45300  LEGO® Education WeDo 2.0 Core Set, Software, a...
# 7            45210                                         MoreToMath
# 8          2045210                     MoreToMath Curriculum Pack 1-2
# 9     SAM-CURIOKIT                              Sam Lab's Curious kit
# 10    SAM-INVENTOR                             Sam Lab's Inventor kit
# 11           45100                              StoryStarter Core Set
# ...
