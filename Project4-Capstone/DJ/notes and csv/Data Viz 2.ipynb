# %%
import numpy as np
import pandas as pd
from gensim.parsing.preprocessing import preprocess_string,preprocess_documents
from gensim import corpora,models, similarities
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_predict, cross_val_score, train_test_split, StratifiedKFold
from sklearn import preprocessing
from scipy import sparse
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.tree import DecisionTreeClassifier

color = sns.color_palette()
# %matplotlib inline
from sklearn import metrics
# Out:
# D:\Drace\Anaconda2\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
testtakers_df = pd.DataFrame({'Test': ['ACT', 'SAT', 'GRE','GMAT','LSAT'],  'Volume': [2090000, 1360000, 414000, 250000, 105883]})

# %%
testtakers_df
# Out:
#    Test   Volume
# 0   ACT  2090000
# 1   SAT  1360000
# 2   GRE   414000
# 3  GMAT   250000
# 4  LSAT   105883

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 6))

sns.set_color_codes("pastel")
sns.barplot(x="Volume", y="Test", data=testtakers_df,
            label="Total", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 2200000), ylabel="",
       xlabel="Number of 2016 Standardized Test Takers in the US")
sns.despine(left=True, bottom=True)

# %%
new_df = pd.DataFrame({'Test': ['ACT', 'SAT', 'GRE','GMAT','LSAT'],  'Volume': [21, 1360000, 414000, 250000, 105883]})

# %%
models_df = pd.DataFrame({'Accuracy Rates': [52.00, 60.92, 76.28, 87.89, 91.12, 93.76], 'Models':['Neural Net Base', 'NN LSTM', 'XGBoost MErr', 'XGB NLTK Loss', 'XGB LDA NLTK Loss', 'XG NLTK CountVec L']})

# %%
sns.set_color_codes("muted")
f, ax = plt.subplots(figsize=(15, 10))
sns.barplot(x="Models", y="Accuracy Rates", data=models_df,
            label="Total", color="b")
