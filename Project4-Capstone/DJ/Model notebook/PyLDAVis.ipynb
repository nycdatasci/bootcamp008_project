# %%
import numpy as np
import pandas as pd
from gensim.parsing.preprocessing import preprocess_string,preprocess_documents
from gensim import corpora,models, similarities
#note pip install pyLDAvis before demo
import pyLDAvis.gensim
import nltk
# Out:
# D:\Drace\Anaconda2\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
dictionary = corpora.Dictionary.load('essays.dict')

# %%
corpus = corpora.MmCorpus('essays.mm')

# %%
lda = models.LdaModel.load('lda.model')

# %%
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 11     10.638553        1       1 -0.128787 -0.031451
# 13      8.707111        1       2 -0.151813 -0.059104
# 15      6.546526        1       3 -0.196487 -0.042133
# 42      6.498803        1       4 -0.112005  0.049028
# 26      5.288198        1       5 -0.196721 -0.015399
# 24      5.107294        1       6 -0.177283  0.001600
# 25      4.849528        1       7 -0.174170  0.029316
# 39      4.004058        1       8 -0.193625  0.023373
# 34      3.588514        1       9 -0.181703  0.022569
# 36      3.587353        1      10 -0.148649 -0.001776
# 31      3.518689        1      11 -0.174562  0.007150
# 44      3.378021        1      12 -0.045044 -0.191484
# 7       2.940123        1      13 -0.040351  0.130829
# 43      2.616020        1      14  0.034837 -0.211183
# 23      2.152604        1      15  0.220102 -0.231771
# 10      1.363952        1      16  0.063929 -0.002599
# ...
