# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import log_loss
from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn import preprocessing
color = sns.color_palette()
# %matplotlib inline

# %%
df_train = pd.read_json('price_vs_median72.json')
df_test = pd.read_json('test.json')

# %%
df_test.head()
# Out:
#       0_per_72  100_per_72  10_per_72  20_per_72  30_per_72  40_per_72  \
# 0         2190        3937     2200.5     2350.0     2375.0     2397.0
# 1         2695        7000     2850.0     2875.0     3500.0     3550.0
# 10        1244        6500     3125.0     3914.0     4122.5     4295.0
# 100       1750        3500     2100.0     2250.0     2393.0     2475.0
# 1000      1700        4000     1700.0     1855.0     1893.0     2300.0
#
#       50_per_72  60_per_72  70_per_72  80_per_72          ...           \
# 0        2495.0     2650.0     2700.0     2840.0          ...
# 1        3650.0     3760.0     3950.0     4000.0          ...
# 10       4325.0     4717.0     4997.0     5680.0          ...
# 100      2500.0     2607.8     2739.9     2899.0          ...
# 1000     2383.0     2571.2     2700.0     2800.0          ...
#
#       latitude  listing_id  longitude                        manager_id  \
# 0      40.7185     7142618   -73.9865  b1b1852c416d78d7765d746cb1b8921f
# 1      40.7278     7210040   -74.0000  d0b5648017832b2427eeb9956d966a14
# 10     40.7330     6832604   -73.9960  e7023646cc4116c721919836cf77a298
# 100    40.6652     6830595   -73.9919  2f512c1b9bc91292647caf69980f3d52
# 1000   40.7807     6843709   -73.9539  c7469ee4e1546cfb4d21c81a8e89c445
#
#           mean_72 median_72  \
# 0     2611.819444    2495.0
# 1     3692.541667    3650.0
# 10    4435.527778    4325.0
# 100   2557.583333    2500.0
# 1000  2367.430556    2383.0
#
#                                                  photos price  \
# 0     [https://photos.renthop.com/2/7142618_1c45a2c8...  2950
# 1     [https://photos.renthop.com/2/7210040_d824cc71...  2850
# 10    [https://photos.renthop.com/2/6832604_36fc72a2...  4800
# 100   [https://photos.renthop.com/2/6830595_d0bb66eb...  2300
# 1000  [https://photos.renthop.com/2/6843709_0ec16bdb...  2750
#
#       price_vs_median_72_new        street_address
# 0                   1.182365     99 Suffolk Street
# 1                   0.780822   176 Thompson Street
# 10                  1.109827            24 5th Ave
# 100                 0.920000      201 Prospect Ave
# 1000                1.154008  155 East 88th Street
#
# [5 rows x 28 columns]

# %%
append_train = pd.read_csv("neighborhood_values_train_72.csv")
df_train = pd.merge(df_train, append_train, how = 'inner', on=['listing_id', 'listing_id'])

append_test = pd.read_csv("neighborhood_values_test_72.csv")
df_test = pd.merge(df_test, append_test, how='inner', on=['listing_id', 'listing_id'])

# %%
df_train['price_vs_median_72_new'] = df_train['price']/df_test['median_72']
df_test['price_vs_median_72_new'] = df_test['price']/df_test['median_72']

# %%
from pandas import to_datetime
import numpy as np
import re


def basic_numeric_features(df):
    df["num_photos"] = df["photos"].apply(len)
    df["num_features"] = df["features"].apply(len)
    df["num_description_words"] = df[
        "description"].apply(lambda x: len(x.split(" ")))
    df['weekday_created'] = df.created.dt.dayofweek
    df["created_year"] = df["created"].dt.year
    df["created_month"] = df["created"].dt.month
    df["created_day"] = df["created"].dt.day
    df["created_hour"] = df["created"].dt.hour
    return df


def num_keyword(df):
    # n_num_keyword: check if a key word makes a difference in terms of
    # interest_level:
    match_list = [map(lambda x: re.search('elevator|cats|dogs|doorman|dishwasher|no fee|laundry|fitness', x.lower()),
                      list(df['features'])[i]) for i in np.arange(0, len(df['features']), 1)]
    nfeat_list = []
    for i in match_list:
        if i is None:
            nfeat_list.append(0)
        else:
            if not any(i):  # check to filter out lists with no all None values
                nfeat_list.append(0)
            else:
                lis1 = []
                map(lambda x: lis1.append(1) if x is None else lis1.append(0), i)
                nfeat_list.append(sum(lis1))

    # new variable n_num_keyfeat_score
    nfeat_score = []
    for i in nfeat_list:
        if i <= 5:
            nfeat_score.append(0)
        elif i == 6:
            nfeat_score.append(1)
        elif i == 7:
            nfeat_score.append(2)
        elif i == 8:
            nfeat_score.append(3)
        elif i == 9:
            nfeat_score.append(4)
        elif i == 10:
            nfeat_score.append(5)
        else:
            nfeat_score.append(6)

    df['n_num_keyfeat_score'] = nfeat_score
    return df


def no_photo(df):
    df['n_no_photo'] = [1 if i == 0 else 0 for i in map(len, df['photos'])]
    return df


def count_caps(df):
    def get_caps(message):
        caps = sum(1 for c in message if c.isupper())
        total_characters = sum(1 for c in message if c.isalpha())
        if total_characters > 0:
            caps = caps / (total_characters * 1.0)
        return caps
    df['amount_of_caps'] = df['description'].apply(get_caps)
    return df


def has_phone(df):
    # http://stackoverflow.com/questions/16699007/regular-expression-to-match-standard-10-digit-phone-number
    phone_regex = "(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})"
    has_phone = df['description'].str.extract(phone_regex)
    df['has_phone'] = [type(item) == unicode for item in has_phone]
    return df


def n_log_price(df):
    # n_price_sqrt improves original 'price' variable smoothing extreme
    # right skew and fat tails.
    # Use either 'price' or this new var to avoid multicolinearity.
    df['n_log_price'] = np.log(df['price'])
    return df


def n_expensive(df):
    # 'Low' interest make 70% population. Statistical analysis shows price
    # among 'Low' interest exhibits the highest kurtosis and skew.
    # n_expensive is 1 when the price is above 75% percentile aggregate
    # prices and 0 otherwise.
    # you can use it along with either price or n_price_sqrt.
    threshold_75p = df[['price']].describe().loc['75%', 'price']
    df['n_expensive'] = [
        1 if i > threshold_75p else 0 for i in list(df['price'])]
    return df


def dist_from_midtown(df):
    from geopy.distance import vincenty
    # pip install geopy
    # https://github.com/geopy/geopy
    # calculates vincenty dist
    # https://en.wikipedia.org/wiki/Vincenty's_formulae
    lat = df['latitude'].tolist()
    long_ = df['longitude'].tolist()
    midtown_lat = 40.7586
    midtown_long = -73.9838
    distance = []
    for i in range(len(lat)):
        distance.append(
            vincenty((lat[i], long_[i]), (midtown_lat, midtown_long)).meters)
    df['distance_from_midtown'] = distance
    return df


def price_vs_mean_30(df):
    # userfriendly for def_nearest_neighbour created earlier.
    # Output: df with price_vs_median for each row
    # The code below solves NA issues and round some results to save execution errors
    temp = pd.read_json("price_vs_median30.json")['price_vs_median_30']
    mean = np.mean(temp) 
    import math
    df['price_vs_median_30'] = [mean if math.isnan(i)== True  else round(i,2) for i in temp]

    return df

def log_price_vs_median(df):
    # n_price_sqrt improves original 'price' variable smoothing extreme
    # right skew and fat tails.
    # Use either 'price' or this new var to avoid multicolinearity.
    df['log_price_vs_median'] = np.log(df['price_vs_median_72_new'])
    return df

# %%
df_train.created = pd.to_datetime(df_train.created)

# %%
#distance for boroughs, not sure if useful


queensCenter = ((40.800760+40.542920)/2,(-73.700272-73.962616)/2)
brookCenter = ((40.739877+40.57042)/2,(-73.864754-74.04344)/2)
bronxCenter = ((40.915255+40.785743)/2,(-73.765274-73.933406)/2)
manhattanCenter = ((40.874663+40.701293)/2,(-73.910759-74.018721)/2)
siCenter = ((40.651812+40.477399)/2,(-74.034547-74.259090)/2)
boroughDict = {}
boroughDict["queens"] = queensCenter
boroughDict["brooklyn"] = brookCenter
boroughDict["bronx"] = bronxCenter
boroughDict["manhattan"] = manhattanCenter
boroughDict["staten"] = siCenter

#This function returns the string representation of the likely borough, given a set of latitude/longitude coordinates
#If the distance to the borough center is too far away from the closest borough, we assume that the location
#is outside of NYC
def get_closest_borough(latitude,longitude,max_dist = 20):
    global boroughDict
    borough_distances = {borough:great_circle(boroughDict[borough],(latitude,longitude)).miles for borough in boroughDict}
    min_borough = min(borough_distances, key=borough_distances.get)
    if borough_distances[min_borough] < max_dist:
        return min_borough 
    else:
        return "outside_nyc"

# %%
def dist_to_nearest_college(df):
    Baruch = (40.7402, -73.9834)
    Columbia = (40.8075, -73.9626)
    Cooper_Union = (40.7299, -73.9903)
    FIT = (40.7475, -73.9951)
    Hunter_College = (40.7685, -73.9657)
    Julliard = (40.7738, -73.9828)
    NYU = (40.7295, -73.9965)
    Pace_University=(40.7111, -74.0049)
    schools = [Baruch,Columbia,Cooper_Union,FIT,Hunter_College, NYU, Pace_University, Julliard
              ]

    from geopy.distance import vincenty
    import numpy as np
    distance = []
    for i in range(0,len(df['latitude']),1):
        lat_long = (list(df['latitude'])[i],list(df['longitude'])[i])
        temp=[]
        for j in schools:
            temp.append(
            vincenty(lat_long, j).meters)
        distance.append(min(temp))
    df['dist_to_nearest_college']= distance
    return df

# %%
df_train['interest_level'] = pd.Categorical(df_train['interest_level'], categories= ['low', 'medium', 'high'], ordered=True)

lbl = preprocessing.LabelEncoder()
lbl.fit(list(df_train['manager_id'].values))
df_train['manager_id'] = lbl.transform(list(df_train['manager_id'].values))
#list of id's to encode
manager_ids = list(df_train['manager_id'].values)
#new var to create
new_var = 'manager_id'#'manager_id_encoded'
#response var
resp_var = 'interest_level'


temp = pd.concat([df_train[new_var], pd.get_dummies(df_train[resp_var])], axis = 1).groupby(new_var).mean()
temp.columns = ['high_frac','low_frac', 'medium_frac']
temp['count'] = df_train.groupby(new_var).count().iloc[:,1]

# compute skill
temp['manager_skill'] = temp['high_frac']*2 + temp['medium_frac']
unranked_managers_ixes = temp['count']<20
ranked_managers_ixes = ~unranked_managers_ixes
mean_values = temp.loc[ranked_managers_ixes, ['high_frac','low_frac', 'medium_frac','manager_skill']].mean()
temp.loc[unranked_managers_ixes,['high_frac','low_frac', 'medium_frac','manager_skill']] = mean_values.values

df_train['Price_P_Room'] = df_train['price']/df_train['bedrooms']
df_train['BB_ratio'] = df_train['bedrooms']/df_train['bathrooms']
df_train['is_studio'] = np.where(df_train['bedrooms'] == 0, '1', '0')
df_train['bathroom_listed'] = np.where(df_train['bathrooms'] == 0, '0', '1')
df_train['n_log_price'] = np.log(df_train['price'])
df_train.bedrooms[df_train.bedrooms == 0] = 1
df_train.bathrooms[df_train.bathrooms ==0] = 1

num_keyword(df_train)
no_photo(df_train)
count_caps(df_train)
n_expensive(df_train)
dist_from_midtown(df_train)
# Out:
# C:\Users\Drace\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Drace\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        bathrooms  bedrooms                       building_id  \
# 0            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 1            1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 2            1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 3            1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 4            1.0         4                                 0
# 5            2.0         4  38a913e46c94a7f46ddf19b756a9640c
# 6            1.0         2  3ba49a93260ca5df92fde024cb4ca61f
# 7            2.0         1  0372927bcb6a0949613ef5bf893bbac7
# 8            1.0         1  a7efbeb58190aa267b4a9121cd0c88c0
# 9            2.0         4                                 0
# 10           1.0         1                                 0
# 11           1.0         1                                 0
# 12           1.0         2  67c9b420da4a365bc26a6cd0ef4a5320
# 13           2.0         2                                 0
# 14           1.0         1                                 0
# 15           1.0         1  bfb9405149bfff42a92980b594c28234
# 16           1.0         2  642cc2c920512ffe2a74c28122f8b47f
# 17           1.0         1                                 0
# 18           1.0         4  cc4c6ae9225df6d2395c4e16c235f7ab
# 19           1.0         1  dc3cae15729b48fec3394f9295671991
# 20           1.0         3  205f95d4a78f1f3befda48b89edc9669
# 21           1.0         2  ecea86b79afa539505aa4bad3ff449c6
# 22           1.0         1  1a6cf9b71da65cdc0cfd5015a75317ac
# 23           1.0         1  a6200d7448037cfee809b2451219f879
# 24           2.0         4  05b871a1e1e0368391160bcefc608e00
# 25           3.5         4  45b4143a9841eb63d7203c4f21a64ff7
# 26           1.0         1  d68497ff1f5ac77f143e5f21817ed6fb
# 27           1.0         1  ec447453d3b8033e14a7b54ba1e13e02
# 28           1.0         1  f06ad2f6f1a821c8efc03dc195d369df
# 29           2.0         2  f115a9bff3a9c4e6eedc9114374b3d74
# ...          ...       ...                               ...
# 49322        1.0         1                                 0
# 49323        1.0         1  e243886a4cac69881c07c6a1f38185bf
# 49324        1.0         1  da2f861e30b1391e8368438efddaa2a7
# 49325        1.0         2  fc0676a4d4fdb4e767faf6414975a0cb
# 49326        2.0         2                                 0
# 49327        1.0         1  93cd24891f8423d45ac587ab1fdb1225
# 49328        1.0         1                                 0
# 49329        1.0         2  80a120d6bc3aba97f40fee8c2204524b
# 49330        1.0         1                                 0
# 49331        1.5         1  d48767c37a934daaf0bbb0e58c755d0c
# 49332        1.0         2                                 0
# 49333        1.0         1  e243886a4cac69881c07c6a1f38185bf
# 12               E 38th St   [Doorman, Elevator, Laundry in Building, No Fee]
# 13        West 63rd Street  [Swimming Pool, Doorman, Fitness Center, No Fe...
# 14          East 56th St..  [Elevator, Multi-Level, Laundry in Building, D...
# 15        East 34th Street  [Doorman, Elevator, Fitness Center, Laundry in...
# 16                1st Ave.                                  [Hardwood Floors]
# 17               Thayer St  [prewar, LOWRISE, EAT IN KITCHEN, SIMPLEX, HAR...
# 18       West 106th Street               [No Fee, Cats Allowed, Dogs Allowed]
# 19              1st Avenue                       [Cats Allowed, Dogs Allowed]
# 20          Madison Avenue   [Doorman, Elevator, Dishwasher, Hardwood Floors]
# 21              E 30th St,  [Elevator, Central A/C, Walk in Closet(s), Par...
# 22        East 35th Street                       [Cats Allowed, Dogs Allowed]
# 23          Liberty Street  [Doorman, Fitness Center, Pool, Elevator, Publ...
# 24                W 18 St.  [Balcony, Doorman, Elevator, Fitness Center, T...
# 25               East 56th  [Roof Deck, Dining Room, Balcony, Doorman, Ele...
# 26              E 81st St.              [Dishwasher, Hardwood Floors, No Fee]
# 27        West 57th Street  [Roof Deck, Doorman, Elevator, Laundry in Buil...
# 28      1215 Morris Avenue                                                 []
# 29              E 79th St.  [Doorman, Elevator, Fitness Center, Pre-War, L...
# ...                    ...                                                ...
# 49322    North 10th Street  [Swimming Pool, Doorman, Fitness Center, Dogs ...
# 49323            W 58th St  [Cats Allowed, Dogs Allowed, Doorman, Elevator...
# 49324     East 78th Street  [Elevator, Laundry in Building, Laundry in Uni...
# 49325         Ridge Blvd.                        [Furnished, Laundry In Unit]
# 49326     West 81st Street     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]
# 49327           8th Avenue  [Doorman, Laundry in Building, Laundry in Unit...
# 49328      Thompson Street                       [Dogs Allowed, Cats Allowed]
# 49329                Water  [Roof Deck, Dining Room, Doorman, Elevator, Fi...
# 49330     East 12th Street                                                 []
# 49331          York Avenue  [Pre-War, Laundry in Building, Dishwasher, Har...
# 49332     West 98th Street     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]
# 49333     West 58th Street  [Doorman, Elevator, Furnished, Pre-War, Dishwa...
# 49334        Nassau Street  [Common Outdoor Space, Cats Allowed, Dogs Allo...
# 49335        Baxter Street                                  [Hardwood Floors]
# 49336      East 3rd Street  [Doorman, Elevator, Laundry in Building, Dishw...
# 49337              E 77 St   [Loft, Multi-Level, Dishwasher, Hardwood Floors]
# 49338     East 87th Street  [Swimming Pool, Dining Room, Doorman, Elevator...
# 49339     East 72nd Street  [Roof Deck, Doorman, Elevator, Fitness Center,...
# 49340            Eldert St                                                 []
# 49341          John Street  [Common Outdoor Space, Cats Allowed, Dogs Allo...
# 49342             W 54 St.  [Doorman, Elevator, Fitness Center, Laundry in...
# 49343          E 76 Street  [Elevator, Multi-Level, Dishwasher, Hardwood F...
# 49344       Charles Street                        [Elevator, Hardwood Floors]
# 49345     East 89th Street                                       [Dishwasher]
# 49346     East 10th Street  [Cats Allowed, No Fee, Doorman, Elevator, Laun...
# 49347              E 30 St  [Elevator, Laundry in Building, Laundry in Uni...
# 49348            Rector Pl  [Common Outdoor Space, Cats Allowed, Dogs Allo...
# 49349     West 45th Street  [Doorman, Elevator, Pre-War, Dogs Allowed, Cat...
# 49350          Wall Street  [Doorman, Elevator, Pre-War, Dogs Allowed, Cat...
# 49351    Park Terrace East                                  [Hardwood Floors]
#
#       interest_level  latitude  listing_id          ...            \
# 0             medium   40.7145     7211212          ...
# 1                low   40.7947     7150865          ...
# 2               high   40.7388     6887163          ...
# 3                low   40.7539     6888711          ...
# 4                low   40.8241     6934781          ...
# 5             medium   40.7429     6894514          ...
# 6                low   40.8012     6930771          ...
# 7                low   40.7427     6867392          ...
# 8             medium   40.8234     6898799          ...
# 9                low   40.7278     6814332          ...
# 10               low   40.7769     6869199          ...
# 11               low   40.8448     7102986          ...
# 12              high   40.7488     6895442          ...
# 13               low   40.7707     6846213          ...
# 14               low   40.7584     7089402          ...
# 15            medium   40.7439     6889043          ...
# 16               low   40.7305     6913348          ...
# 17               low   40.8643     6894111          ...
# 18               low   40.7999     6900220          ...
# 19               low   40.7328     6848536          ...
# 20               low   40.7454     6858062          ...
# 21            medium   40.7427     6836760          ...
# 22               low   40.7447     6866830          ...
# 23               low   40.7074     6885927          ...
# 24            medium   40.7391     7120132          ...
# 25               low   40.7584     6933499          ...
# 26            medium   40.7728     6921632          ...
# 27               low   40.7709     6913084          ...
# 28              high   40.8335     6907079          ...
# 29               low   40.7716     6925264          ...
# ...              ...       ...         ...          ...
# 49322            low   40.7176     6921019          ...
# 49323            low   40.7655     6926146          ...
# 49324         medium   40.7721     6844805          ...
# 49325         medium   40.6182     6943991          ...
# 49326            low   40.7829     6822618          ...
# 49327            low   40.7637     6918969          ...
# 49328            low   40.7293     6921162          ...
# 49329            low   40.7075     6819357          ...
# 49330            low   40.7287     6893263          ...
# 49331            low   40.7769     6873182          ...
# 49332            low   40.7957     7114685          ...
# 49333            low   40.7655     6924210          ...
# 49334            low   40.7095     6884807          ...
# 49335         medium   40.7179     6825168          ...
# 49336            low   40.7222     6911061          ...
# 49337         medium   40.7708     6942494          ...
# 49338            low   40.7766     6819478          ...
# 49339            low   40.7695     6878391          ...
# 49340            low   40.6865     6871559          ...
# 49341            low   40.7090     6933865          ...
# 49342           high   40.7645     6837242          ...
# 49343            low   40.7728     6815109          ...
# 49344            low   40.7350     6871681          ...
# 49345            low   40.7889     6856001          ...
# 49346         medium   40.7296     6913833          ...
# 49347         medium   40.7426     7098690          ...
# 49348            low   40.7102     6822449          ...
# 49349            low   40.7601     6881461          ...
# 49350            low   40.7066     6841891          ...
# 49351            low   40.8699     6858245          ...
#
#        Price_P_Room  BB_ratio is_studio  bathroom_listed  n_log_price  \
# 0       1000.000000  2.000000         0                1     8.006368
# 1       2732.500000  2.000000         0                1     8.606119
# 2       2850.000000  1.000000         0                1     7.955074
# 3       3275.000000  1.000000         0                1     8.094073
# 4        837.500000  4.000000         0                1     8.116716
# 5       1998.750000  2.000000         0                1     8.986572
# 6       1800.000000  2.000000         0                1     8.188689
# 7       5645.000000  0.500000         0                1     8.638525
# 8       1725.000000  1.000000         0                1     7.452982
# 9       1450.000000  2.000000         0                1     8.665613
# 10              inf  0.000000         1                1     7.575585
# 11      1675.000000  1.000000         0                1     7.423568
                (tube_lat_long.iloc[:,0][i],tube_lat_long.iloc[:,1][i]))

    from geopy.distance import vincenty
    import numpy as np
    distance = []
    for i in range(0,len(df['latitude']),1):
        lat_long = (list(df['latitude'])[i],list(df['longitude'])[i])
        temp=[]
        for j in stations:
            temp.append(
            vincenty(lat_long, j).meters)
        distance.append(min(temp))

    df['dist_to_nearest_tube']= distance
    return df

# %%
def manager_skill(df):
    #new var to create
    new_var = 'manager_id'#'manager_id_encoded'
    #response var
    resp_var = 'interest_level'
    # Step 1: create manager_skill ranking from training set:
    train_df = pd.read_json("train.json") # upload training scores => test data cannot create a rank skill
    temp = pd.concat([train_df[new_var], pd.get_dummies(train_df[resp_var])], axis = 1).groupby(new_var).mean()
    temp.columns = ['high_frac','low_frac', 'medium_frac']
    temp['count'] = train_df.groupby(new_var).count().iloc[:,1]
    temp['manager_skill'] = temp['high_frac']*2 + temp['medium_frac']
    # Step 2: fill working dataset (e.g. test set) with ranking figures and replace new manager_id not present in our
    # training set with an average assumption:
    manager_skill=[]
    for i in df['manager_id']:
        for j in temp.index:
            if i==j:
                manager_skill.append(temp['manager_skill'][j])
            else:
                manager_skill.append(-1) # we flag this to replace it for average later and control for manager_ids not present in training _df
    # Step 3: Replacing new manager_id scores not available in training set with the mean: 
    mean_manager_skill= np.mean(manager_skill)
    manager_skill_clean = [mean_manager_skill if i==-1 else i for i in manager_skill] # replace NA (labelled as -1 earlier) for the mean

    df['manager_skill'] = manager_skill_clean
    return df

# %%
#apply all features to check
regex_col0 = {"nofee":'no fee', "doorman": 'doorman', "fitness": 'fitness|swimming', "hardwood": "hardwood",\
             "dishwash": 'dishwasher', "preWar": 'prewar|pre-war', 'furnished': 'furnished', "laundry": 'laundry',\
            "allow_pets": 'cats|dogs'}
import re

def create_regex_col0(df,regex,colname):
    def find_regex(lis):
        text = ' '.join(lis)
        r = re.compile(regex,flags=re.IGNORECASE)
        matches = r.findall(text)
        return len(matches)
    df[colname] = df['features'].apply(find_regex)
    
for name, regex in regex_col0.items():
    create_regex_col0(df_train,regex,name)

# %%
#apply some samples for desc, jake has updated version
regex_col = {"subway":'train|trains|subway|line', "luxurious": 'luxury', "quiet_nei": 'quiet', "available": "available (immediately|now)",\
             "space_desc": 'foot|feet', "buzzword": 'must see'}

def create_regex_col(df,regex,colname):
    def find_regex(text):
        r = re.compile(regex,flags=re.IGNORECASE)
        matches = r.findall(text)
        return len(matches)
    df[colname] = df['description'].apply(find_regex)

for name, regex in regex_col.items():
    create_regex_col(df_train,regex,name)

# %%
df_train.allow_pets.describe()
# Out:
# count    49352.000000
# mean         0.923894
# std          0.981502
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max          4.000000
# Name: allow_pets, dtype: float64

# %%
lbl = preprocessing.LabelEncoder()
lbl.fit(list(df_train['building_id'].values))
df_train['building_id'] = lbl.transform(list(df_train['building_id'].values))

# %%
#tack on manager skill

# %%
drace_df = df_train.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_
# 49338  Full-Time Doorman PET FRIENDLYElevator GYMLaun...     East 87th Street
# 49339  This is a Great Opportunity to Rent an Excelle...     East 72nd Street
# 49340                                                               Eldert St
# 49341  Incredibly sunny and spacious studio apartment...          John Street
# 49342  LUXURY BUILDING IN MIDTOWN WEST, 24 HR DOORMAN...             W 54 St.
# 49343  Huge true king size one bedroom in an elevator...          E 76 Street
# 49344  Charming one bedroom! Hardwood floors, sunny, ...       Charles Street
# 49345  **89th & Park Ave! (block from the central par...     East 89th Street
# 49346  24hr Doorman Luxury building in the heart of t...     East 10th Street
# 49347  30TH/3RD, MASSIVE CONV 2BR IN LUXURY FULL SERV...              E 30 St
# 49348  HIGH END condo finishes, swimming pool, and ki...            Rector Pl
# 49349  Large Renovated One Bedroom Apartment with Sta...     West 45th Street
# 49350  Stylishly sleek studio apartment with unsurpas...          Wall Street
# 49351  Look no further!!!  This giant 2 bedroom apart...    Park Terrace East
#
#                                                 features interest_level  \
# 0                                                     []         medium
# 1      [Doorman, Elevator, Fitness Center, Cats Allow...            low
# 2      [Laundry In Building, Dishwasher, Hardwood Flo...           high
# 3                              [Hardwood Floors, No Fee]            low
# 4                                              [Pre-War]            low
# 5                                                     []         medium
# 6      [prewar, elevator, Dogs Allowed, Cats Allowed,...            low
# 7      [Doorman, Elevator, Pre-War, Terrace, Laundry ...            low
# 8      [Cats Allowed, Dogs Allowed, Elevator, Laundry...         medium
# 9                          [Dishwasher, Hardwood Floors]            low
# 10                                                    []            low
# 11     [prewar, dishwasher, HIGHRISE, ROOFDECK, EAT I...            low
# 12      [Doorman, Elevator, Laundry in Building, No Fee]           high
# 13     [Swimming Pool, Doorman, Fitness Center, No Fe...            low
# 14     [Elevator, Multi-Level, Laundry in Building, D...            low
# 15     [Doorman, Elevator, Fitness Center, Laundry in...         medium
# 16                                     [Hardwood Floors]            low
# 17     [prewar, LOWRISE, EAT IN KITCHEN, SIMPLEX, HAR...            low
# 18                  [No Fee, Cats Allowed, Dogs Allowed]            low
# 19                          [Cats Allowed, Dogs Allowed]            low
# 20      [Doorman, Elevator, Dishwasher, Hardwood Floors]            low
# 21     [Elevator, Central A/C, Walk in Closet(s), Par...         medium
# 22                          [Cats Allowed, Dogs Allowed]            low
# 23     [Doorman, Fitness Center, Pool, Elevator, Publ...            low
# 24     [Balcony, Doorman, Elevator, Fitness Center, T...         medium
# 25     [Roof Deck, Dining Room, Balcony, Doorman, Ele...            low
# 26                 [Dishwasher, Hardwood Floors, No Fee]         medium
# 27     [Roof Deck, Doorman, Elevator, Laundry in Buil...            low
# 28                                                    []           high
# 29     [Doorman, Elevator, Fitness Center, Pre-War, L...            low
# ...                                                  ...            ...
# 49322  [Swimming Pool, Doorman, Fitness Center, Dogs ...            low
# 49323  [Cats Allowed, Dogs Allowed, Doorman, Elevator...            low
# 49324  [Elevator, Laundry in Building, Laundry in Uni...         medium
# 49325                       [Furnished, Laundry In Unit]         medium
# 49326     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]            low
# 49327  [Doorman, Laundry in Building, Laundry in Unit...            low
# 49328                       [Dogs Allowed, Cats Allowed]            low
# 49329  [Roof Deck, Dining Room, Doorman, Elevator, Fi...            low
# 49330                                                 []            low
# 49331  [Pre-War, Laundry in Building, Dishwasher, Har...            low
# 49332     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]            low
# 49333  [Doorman, Elevator, Furnished, Pre-War, Dishwa...            low
# 49334  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 
Doorman, Elevator, Fitness Center, Cats Allow...            low
# 2      [Laundry In Building, Dishwasher, Hardwood Flo...           high
# 3                              [Hardwood Floors, No Fee]            low
# 4                                              [Pre-War]            low
# 5                                                     []         medium
# 6      [prewar, elevator, Dogs Allowed, Cats Allowed,...            low
# 7      [Doorman, Elevator, Pre-War, Terrace, Laundry ...            low
# 8      [Cats Allowed, Dogs Allowed, Elevator, Laundry...         medium
# 9                          [Dishwasher, Hardwood Floors]            low
# 10                                                    []            low
# 11     [prewar, dishwasher, HIGHRISE, ROOFDECK, EAT I...            low
# 12      [Doorman, Elevator, Laundry in Building, No Fee]           high
# 13     [Swimming Pool, Doorman, Fitness Center, No Fe...            low
# 14     [Elevator, Multi-Level, Laundry in Building, D...            low
# 15     [Doorman, Elevator, Fitness Center, Laundry in...         medium
# 16                                     [Hardwood Floors]            low
# 17     [prewar, LOWRISE, EAT IN KITCHEN, SIMPLEX, HAR...            low
# 18                  [No Fee, Cats Allowed, Dogs Allowed]            low
# 19                          [Cats Allowed, Dogs Allowed]            low
# 20      [Doorman, Elevator, Dishwasher, Hardwood Floors]            low
# 21     [Elevator, Central A/C, Walk in Closet(s), Par...         medium
# 22                          [Cats Allowed, Dogs Allowed]            low
# 23     [Doorman, Fitness Center, Pool, Elevator, Publ...            low
# 24     [Balcony, Doorman, Elevator, Fitness Center, T...         medium
# 25     [Roof Deck, Dining Room, Balcony, Doorman, Ele...            low
# 26                 [Dishwasher, Hardwood Floors, No Fee]         medium
# 27     [Roof Deck, Doorman, Elevator, Laundry in Buil...            low
# 28                                                    []           high
# 29     [Doorman, Elevator, Fitness Center, Pre-War, L...            low
# ...                                                  ...            ...
# 49322  [Swimming Pool, Doorman, Fitness Center, Dogs ...            low
# 49323  [Cats Allowed, Dogs Allowed, Doorman, Elevator...            low
# 49324  [Elevator, Laundry in Building, Laundry in Uni...         medium
# 49325                       [Furnished, Laundry In Unit]         medium
# 49326     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]            low
# 49327  [Doorman, Laundry in Building, Laundry in Unit...            low
# 49328                       [Dogs Allowed, Cats Allowed]            low
# 49329  [Roof Deck, Dining Room, Doorman, Elevator, Fi...            low
# 49330                                                 []            low
# 49331  [Pre-War, Laundry in Building, Dishwasher, Har...            low
# 49332     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]            low
# 49333  [Doorman, Elevator, Furnished, Pre-War, Dishwa...            low
# 49334  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 49335                                  [Hardwood Floors]         medium
# 49336  [Doorman, Elevator, Laundry in Building, Dishw...            low
# 49337   [Loft, Multi-Level, Dishwasher, Hardwood Floors]         medium
# 49338  [Swimming Pool, Dining Room, Doorman, Elevator...            low
# 49339  [Roof Deck, Doorman, Elevator, Fitness Center,...            low
# 49340                                                 []            low
# 49341  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 49342  [Doorman, Elevator, Fitness Center, Laundry in...           high
# 49343  [Elevator, Multi-Level, Dishwasher, Hardwood F...            low
# 49344                        [Elevator, Hardwood Floors]            low
# 49345                                       [Dishwasher]            low
# 49346  [Cats Allowed, No Fee, Doorman, Elevator, Laun...         medium
# 49347  [Elevator, Laundry in Building, Laundry in Uni...         medium
# 49348  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 49349  [Doorman, Elevator, Pre-War, Dogs Allowed, Cat...            low
# 49350  [Doorman, Elevator, Pre-War, Dogs Allowed, Cat...            low
# 
# 2              8             4                     94               6
# 3              3             2                     80               0
# 4              3             1                     68               3
# 5              5             0                      9               1
# 6             10             8                     87               2
# 7              5             8                    134               2
# 8              5             4                      4               2
# 9              9             2                    166               5
# 10             1             0                     28               3
# 11             5             7                    105               4
# 12             4             4                    108               1
# 13             6             6                     76               5
# 14             6             5                     86               2
# 15             2             5                     70               0
# 16             5             1                     49               4
# 17             8             5                    172               1
# 18             0             3                      9               2
# 19            32             2                      9               5
# 20             6             4                    143               1
# 21             5             9                     43               3
# 22             0             2                      9               2
# 23             4            10                    112               6
# 24             6            12                    137               1
# 25             7            12                    118               2
# 26             6             3                     63               0
# 27             6             8                    106               4
# 28             1             0                     35               3
# 29             1             8                     51               1
# ...          ...           ...                    ...             ...
# 49322          6             5                     79               0
# 49323          9             5                      1               1
# 49324          4             8                    108               4
# 49325          6             2                     70               4
# 49326          2             4                     80               1
# 49327          3             6                     90               6
# 49328          3             2                     26               0
# 49329          4            12                     91               6
# 49330          4             0                    105               1
# 49331          7             5                     39               3
# 49332          8             4                     84               0
# 49333          1             7                    187               1
# 49334          8             5                     52               5
# 49335          3             1                     63               1
# 49336          8             6                     99               4
# 49337          3             4                     98               4
# 49338          4             9                    102               6
# 49339          4             9                    122               4
# 49340          0             0                      9               3
# 49341          4             7                     81               2
# 49342          3            10                    117               3
# 49343          4             5                     56               5
# 49344          5             2                     40               3
# 49345          8             1                    108               0
# 49346          8            10                     45               4
# 49347          4             6                    115               3
# 49348          8             8                    191               0
# 49349          3             5                     84               5
# 49350          9             5                     99               4
# 49351          7             1                    133               1
#
#        created_year  created_month  created_day  created_hour
# 0              2016              6           24             7
# 1              2016              6           12            12
# 2              2016              4           17             3
# 3              2016              4           18             2
# 4              2016              4           28             1
# 5              2016              4           19             4
# 6              2016              4           27             3
# 7              2016              4           13             6
# 8              2016              4           20             2
# 9              2016              4            2             2
# 10             2016              4           14             1
# 11             2016              6            3             3
# 12             2016              4           19             5
# 13             2016              4            9             1
# 14             2016              6            1             3
# 15             2016              4           18             2
# 16             2016              4           22             5
# 17             2016              4           19             3
# 18             2016              4           20             4
# 19             2016              4            9             3
# 20             2016              4           12             2
# 21             2016              4            7             2
# 22             2016              4           13             5
# 23             2016              4           17             2
# 24             2016              6            7             4
# 25             2016              4           27             6
# 26             2016              4           25             2
# 27             2016              4           22             5
# 28             2016              4           21             5
# 29             2016              4           26             2
# ...             ...            ...          ...           ...
# 49322          2016              4           25             1
# 49323          2016              4           26             4
# 49324          2016              4            8             5
# 49325          2016              4           29            15
# 49326          2016              4            5             1
# 49327          2016              4           24             3
# 49328          2016              4           25             1
# 49329          2016              4            3             3
# 49330          2016              4           19             2
# 49331          2016              4           14             5
# 49332          2016              6            6             1
# 49333          2016              4           26             2
# 49334          2016              4           16            16
# 49335          2016              4            5             4
# 49336          2016              4           22             3
# 49337          2016              4           29             5
# 49338          2016              4            3             5
# 49339          2016              4           15             5
# 49340          2016              4           14             3
# 49341          2016              4           27            12
# 49342          2016              4            7             2
# 49343          2016              4            2             3
# 49344          2016              4           14             3
# 49334  This spacious two bedroom apartment features e...        Nassau Street
# 49335  Great Lower East Side one bedroom.Well maintai...        Baxter Street
# 49336  THIS LARGE AND SPACIOUS 3 BD/ONE BA APARTMENT ...      East 3rd Street
# 49337  77TH ST! FULLY GUT RENOV STUDIO! HI CEIL! XPSD...              E 77 St
# 49338  Full-Time Doorman PET FRIENDLYElevator GYMLaun...     East 87th Street
# 49339  This is a Great Opportunity to Rent an Excelle...     East 72nd Street
# 49340                                                               Eldert St
# 49341  Incredibly sunny and spacious studio apartment...          John Street
# 49342  LUXURY BUILDING IN MIDTOWN WEST, 24 HR DOORMAN...             W 54 St.
# 49343  Huge true king size one bedroom in an elevator...          E 76 Street
# 49344  Charming one bedroom! Hardwood floors, sunny, ...       Charles Street
# 49345  **89th & Park Ave! (block from the central par...     East 89th Street
# 49346  24hr Doorman Luxury building in the heart of t...     East 10th Street
# 49347  30TH/3RD, MASSIVE CONV 2BR IN LUXURY FULL SERV...              E 30 St
# 49348  HIGH END condo finishes, swimming pool, and ki...            Rector Pl
# 49349  Large Renovated One Bedroom Apartment with Sta...     West 45th Street
# 49350  Stylishly sleek studio apartment with unsurpas...          Wall Street
# 49351  Look no further!!!  This giant 2 bedroom apart...    Park Terrace East
#
#                                                 features interest_level  \
# 0                                                     []         medium
# 1      [Doorman, Elevator, Fitness Center, Cats Allow...            low
# 2      [Laundry In Building, Dishwasher, Hardwood Flo...           high
# 3                              [Hardwood Floors, No Fee]            low
# 4                                              [Pre-War]            low
# 5                                                     []         medium
# 6      [prewar, elevator, Dogs Allowed, Cats Allowed,...            low
# 7      [Doorman, Elevator, Pre-War, Terrace, Laundry ...            low
# 8      [Cats Allowed, Dogs Allowed, Elevator, Laundry...         medium
# 9                          [Dishwasher, Hardwood Floors]            low
# 10                                                    []            low
# 11     [prewar, dishwasher, HIGHRISE, ROOFDECK, EAT I...            low
# 12      [Doorman, Elevator, Laundry in Building, No Fee]           high
# 13     [Swimming Pool, Doorman, Fitness Center, No Fe...            low
# 14     [Elevator, Multi-Level, Laundry in Building, D...            low
# 15     [Doorman, Elevator, Fitness Center, Laundry in...         medium
# 16                                     [Hardwood Floors]            low
# 17     [prewar, LOWRISE, EAT IN KITCHEN, SIMPLEX, HAR...            low
# 18                  [No Fee, Cats Allowed, Dogs Allowed]            low
# 19                          [Cats Allowed, Dogs Allowed]            low
# 20      [Doorman, Elevator, Dishwasher, Hardwood Floors]            low
# 21     [Elevator, Central A/C, Walk in Closet(s), Par...         medium
# 22                          [Cats Allowed, Dogs Allowed]            low
# 23     [Doorman, Fitness Center, Pool, Elevator, Publ...            low
# 24     [Balcony, Doorman, Elevator, Fitness Center, T...         medium
# 25     [Roof Deck, Dining Room, Balcony, Doorman, Ele...            low
# 26                 [Dishwasher, Hardwood Floors, No Fee]         medium
# 27     [Roof Deck, Doorman, Elevator, Laundry in Buil...            low
# 28                                                    []           high
# 29     [Doorman, Elevator, Fitness Center, Pre-War, L...            low
# ...                                                  ...            ...
# 49322  [Swimming Pool, Doorman, Fitness Center, Dogs ...            low
# 49323  [Cats Allowed, Dogs Allowed, Doorman, Elevator...            low
# 49324  [Elevator, Laundry in Building, Laundry in Uni...         medium
# 49325                       [Furnished, Laundry In Unit]         medium
# 49326     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]            low
# 49327  [Doorman, Laundry in Building, Laundry in Unit...            low
# 49328                       [Dogs Allowed, Cats Allowed]            low
# 49329  [Roof Deck, Dining Room, Doorman, Elevator, Fi...            low
# 49330                                                 []            low
# 49331  [Pre-War, Laundry in Building, Dishwasher, Har...            low
# 49332     [Doorman, Pre-War, Dogs Allowed, Cats Allowed]            low
# 49333  [Doorman, Elevator, Furnished, Pre-War, Dishwa...            low
# 49334  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 49335                                  [Hardwood Floors]         medium
# 49336  [Doorman, Elevator, Laundry in Building, Dishw...            low
# 49337   [Loft, Multi-Level, Dishwasher, Hardwood Floors]         medium
# 49338  [Swimming Pool, Dining Room, Doorman, Elevator...            low
# 49339  [Roof Deck, Doorman, Elevator, Fitness Center,...            low
# 49340                                                 []            low
# 49341  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 49342  [Doorman, Elevator, Fitness Center, Laundry in...           high
# 49343  [Elevator, Multi-Level, Dishwasher, Hardwood F...            low
# 49344                        [Elevator, Hardwood Floors]            low
# 49345                                       [Dishwasher]            low
# 49346  [Cats Allowed, No Fee, Doorman, Elevator, Laun...         medium
# 49347  [Elevator, Laundry in Building, Laundry in Uni...         medium
# 49348  [Common Outdoor Space, Cats Allowed, Dogs Allo...            low
# 49349  [Doorman, Elevator, Pre-War, Dogs Allowed, Cat...            low
# 49350  [Doorman, Elevator, Pre-War, Dogs Allowed, Cat...            low
# 49351                                  [Hardwood Floors]            low
#
#        latitude  listing_id          ...           num_features  \
# 0       40.7145     7211212          ...                      0
# 1       40.7947     7150865          ...                      5
# 2       40.7388     6887163          ...                      4
# 3       40.7539     6888711          ...                      2
# 4       40.8241     6934781          ...                      1
# 5       40.7429     6894514          ...                      0
# 6       40.8012     6930771          ...                      8
# 7       40.7427     6867392          ...                      8
# 8       40.8234     6898799          ...                      4
# 9       40.7278     6814332          ...                      2
# 10      40.7769     6869199          ...                      0
# 11      40.8448     7102986          ...                      7
# 12      40.7488     6895442          ...                      4
# 13      40.7707     6846213          ...                      6
# 14      40.7584     7089402          ...                      5
# 15      40.7439     6889043          ...                      5
# 16      40.7305     6913348          ...                      1
# 17      40.8643     6894111          ...                      5
# 18      40.7999     6900220          ...                      3
# 19      40.7328     6848536          ...                      2
# 20      40.7454     6858062          ...                      4
# 21      40.7427     6836760          ...                      9
# 22      40.7447     6866830          ...                      2
# 23      40.7074     6885927          ...                     10
# 24      40.7391     7120132          ...                     12
# 25      40.7584     6933499          ...                     12
# 26      40.7728     6921632          ...                      3
# 27      40.7709     6913084          ...                      8
# 28      40.8335     6907079          ...                      0
# 29      40.7716     6925264          ...                      8
# ...         ...         ...          ...                    ...
# 49322   40.7176     6921019          ...                      5
# 49323   40.7655     6926146          ...                      5
# 49324   40.7721     6844805          ...                      8
# 49325   40.6182     6943991          ...                      2
# 49326   40.7829     6822618          ...                      4
# 49327   40.7637     6918969          ...                      6
# 49328   40.7293     6921162          ...                      2
# 49329   40.7075     6819357          ...                     12
# 49330   40.7287     6893263          ...                      0
# 49331   40.7769     6873182          ...                      5
# 49332   40.7957     7114685          ...                      4
# 49333   40.7655     6924210          ...                      7
# 49334   40.7095     6884807          ...                      5
# 49335   40.7179     6825168          ...                      1
# 49336   40.7222     6911061          ...                      6
# 49337   40.7708     6942494          ...                      4
# 49338   40.7766     6819478          ...                      9
# 49339   40.7695     6878391          ...                      9
# 49340   40.6865     6871559          ...                      0
# 49341   40.7090     6933865          ...                      7
# 49342   40.7645     6837242          ...                     10
# 49343   40.7728     6815109          ...                      5
# 49344   40.7350     6871681          ...                      2
# 49345   40.7889     6856001          ...                      1
# 49346   40.7296     6913833          ...                     10
# 49347   40.7426     7098690          ...                      6
# 49348   40.7102     6822449          ...                      8
# 49349   40.7601     6881461          ...                      5
# 49350   40.7066     6841891          ...                      5
# 49351   40.8699     6858245          ...                      1
#
#        num_description_words weekday_created  created_year  created_month  \
# 0                         95               4          2016              6
# 1                          9               6          2016              6
# 2                         94               6          2016              4
# 3                         80               0          2016              4
# 4                         68               3          2016              4
# 5                          9               1          2016              4
# 6                         87               2          2016              4
# 7                        134               2          2016              4
# 8                          4               2          2016              4
# 9                        166               5          2016              4
# 10                        28               3          2016              4
# 11                       105               4          2016              6
# 12                       108               1          2016              4
# 13                        76               5          2016              4
# 14                        86               2          2016              6
# 15                        70               0          2016              4
# 16                        49               4          2016              4
# 17                       172               1          2016              4
# 18                         9               2          2016              4
# 19                         9               5          2016              4
# 20                       143               1          2016              4
# 21                        43               3          2016              4
# 22                         9               2          2016              4
# 23                       112               6          2016              4
# 24                       137               1          2016              6
# 25                       118               2          2016              4
# 26                        63               0          2016              4
# 27                       106               4          2016              4
# 28                        35               3          2016              4
# 29                        51               1          2016              4
# ...                      ...             ...           ...            ...
# 49322                     79               0          2016              4
# 49323                      1               1          2016              4
# 49324                    108               4          2016              4
# 49325                     70               4          2016              4
# 49326                     80               1          2016              4
# 49327                     90               6          2016              4
# 49328                     26               0          2016              4
# 49329                     91               6          2016              4
# 49330                    105               1          2016              4
# 49331                     39               3          2016              4
# 49332                     84               0          2016              6
# 49333                    187               1          2016              4
# 49334                     52               5          2016              4
# 49335                     63               1          2016              4
# 49336                     99               4          2016              4
# 49337                     98               4          2016              4
# 49338                    102               6          2016              4
# 49339                    122               4          2016              4
# 49340                      9               3          2016              4
# 49341                     81               2          2016              4
# 49342                    117               3          2016              4
# 49343                     56               5          2016              4
# 49344                     40               3          2016              4
# 49345                    108               0          2016              4
# 49346                     45               4          2016              4
# 49347                    115               3          2016              6
# 49348                    191               0          2016              4
# 49349                     84               5          2016              4
# 49350                     99               4          2016              4
# 49351                    133               1          2016              4
#
#       created_day  created_hour  price_vs_median_72_new  log_price_vs_median  \
# 0              24             7                1.202405             0.184324
# 1              12            12                1.497260             0.403637
# 2              17             3                0.838235            -0.176456
# 3              18             2                0.992424            -0.007605
# 4              28             1                0.647030            -0.435362
# 5              19             4                0.888580            -0.118130
# 6              27             3                1.220339             0.199129
# 7              13             6                3.051351             1.115585
# 8              20             2                0.543821            -0.609135
 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
                'dist_to_nearest_college']
x = drace_df[feats_used]
y = drace_df["interest_level"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
rf = RandomForestClassifier(n_estimators=1000)
rf.fit(x_train[feats_used], y_train)
y_pred = rf.predict_proba(x_test[feats_used])
log_loss(y_test, y_pred)
# Out:
# 0.57041602642790534

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(rf.predict(x_test), y_test)

# %%
pd.Series(index = feats_used, data = rf.feature_importances_).sort_values().plot(kind = 'bar')

# %%
#compute cross-validation score accuracy across 5 folds
#cross_val_scores = cross_val_score(rf,x,y,cv=5)
#print "5-fold accuracies:\n",cross_val_scores
#print "Mean cv-accuracy:",np.mean(cross_val_scores)
#print "Std of cv-accuracy:",np.std(cross_val_scores)

# %%
drace_df['price_vs_median_72_new'] = drace_df['price']/df_test['median_72']

# %%
drace_df.columns
# Out:
# Index([              u'bathrooms',                u'bedrooms',
#                    u'building_id',                 u'created',
#                    u'description',         u'display_address',
#                       u'features',          u'interest_level',
#                       u'latitude',              u'listing_id',
#                      u'longitude',              u'manager_id',
#                         u'photos',                   u'price',
#             u'price_vs_median_72',          u'street_address',
#                       u'0_per_72',               u'10_per_72',
#                      u'20_per_72',               u'30_per_72',
#                      u'40_per_72',               u'50_per_72',
#                      u'60_per_72',               u'70_per_72',
#                      u'80_per_72',               u'90_per_72',
#                     u'100_per_72',               u'median_72',
#                        u'mean_72',            u'Price_P_Room',
#                       u'BB_ratio',               u'is_studio',
#                u'bathroom_listed',             u'n_log_price',
#            u'n_num_keyfeat_score',              u'n_no_photo',
#                 u'amount_of_caps',             u'n_expensive',
#          u'distance_from_midtown',                u'dishwash',
#                      u'furnished',                 u'laundry',
#                         u'preWar',                 u'fitness',
#                       u'hardwood',                   u'nofee',
#                        u'doorman',              u'allow_pets',
#                      u'available',              u'space_desc',
#                      u'luxurious',                  u'subway',
#                       u'buzzword',               u'quiet_nei',
#                      u'high_frac',                u'low_frac',
#                    u'medium_frac',                   u'count',
#                  u'manager_skill', u'dist_to_nearest_college',
#                      u'has_phone',              u'num_photos',
#                   u'num_features',   u'num_description_words',
#                u'weekday_created',            u'created_year',
#                  u'created_month',             u'created_day',
#                   u'created_hour',  u'price_vs_median_72_new',
#            u'log_price_vs_median',    u'dist_to_nearest_tube'],
#       dtype='object')

# %%
#some baseline features according to some good rule of thumbs for gbm params

feats_used = ['bathrooms', 'bedrooms', 'created_day', 'latitude', 'longitude',\
             'n_log_price', 'price_vs_median_72', 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
              'dist_to_nearest_college']
from sklearn.ensemble import GradientBoostingClassifier
x = drace_df[feats_used]
y = drace_df["interest_level"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
gbm0 = GradientBoostingClassifier(n_estimators=1000, max_features=5)
gbm0.fit(x_train,y_train)
y_pred2 = gbm0.predict_proba(x_test[feats_used])
log_loss(y_test, y_pred2)
# Out:
# 0.57944362881710565

# %%
pd.Series(index = feats_used, data = gbm0.feature_importances_).sort_values().plot(kind = 'bar')

# %%
#some baseline features according to some good rule of thumbs for gbm params

feats_used = ['bathrooms', 'manager_skill', 'bedrooms', 'created_day', 'latitude', 'longitude',\
             'n_log_price', 'price_vs_median_72', 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
                'dist_to_nearest_college']
from sklearn.ensemble import GradientBoostingClassifier
x = drace_df[feats_used]
y = drace_df["interest_level"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
gbm1 = GradientBoostingClassifier(n_estimators=1000, max_features=5)
gbm1.fit(x_train,y_train)
y_pred2 = gbm1.predict_proba(x_test[feats_used])
log_loss(y_test, y_pred2)
# Out:
# 0.53293676579902272

# %%
pd.Series(index = feats_used, data = gbm1.feature_importances_).sort_values().plot(kind = 'bar')

# %%
from sklearn.grid_search import GridSearchCV
param_test1 = {'n_estimators':range(20,81,10)}
gsearch1 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, min_samples_split=500,min_samples_leaf=50,max_depth=8,max_features='sqrt',subsample=0.8),\
                        param_grid = param_test1, scoring='log_loss',n_jobs=4,iid=False, cv=5)
gsearch1.fit(drace_df[feats_used],y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=8, max_features='sqrt', max_leaf_nodes=None,
#               min_samples_leaf=50, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'n_estimators': [20, 30, 40, 50, 60, 70, 80]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='log_loss', verbose=0)

# %%
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# ([mean: -0.61870, std: 0.00500, params: {'n_estimators': 20},
#   mean: -0.59234, std: 0.00498, params: {'n_estimators': 30},
#   mean: -0.57989, std: 0.00677, params: {'n_estimators': 40},
#   mean: -0.57125, std: 0.00543, params: {'n_estimators': 50},
#   mean: -0.56716, std: 0.00595, params: {'n_estimators': 60},
#   mean: -0.56293, std: 0.00620, params: {'n_estimators': 70},
#   mean: -0.56005, std: 0.00605, params: {'n_estimators': 80}],
#  {'n_estimators': 80},
#  -0.56004877662787267)

# %%
#DO NOT RUN THESE PARAM TESTS UNLESS YOU WANT TO VALIDATE FOR YOURSELF.  TAKES VERY LONG!!!
param_test2 = {'max_depth':range(1,16,2), 'min_samples_split':range(200,1001,200)}
gsearch2 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=80, max_features='sqrt',subsample=0.8),\
                        param_grid = param_test2, scoring='log_loss',n_jobs=4,iid=False, cv=5)
gsearch2.fit(drace_df[feats_used],y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=3, max_features='sqrt', max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=80,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'min_samples_split': [200, 400, 600, 800, 1000], 'max_depth': [1, 3, 5, 7, 9, 11, 13, 15]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='log_loss', verbose=0)

# %%
gsearch2.grid_scores_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# ([mean: -0.65077, std: 0.00638, params: {'min_samples_split': 200, 'max_depth': 1},
#   mean: -0.64940, std: 0.00530, params: {'min_samples_split': 400, 'max_depth': 1},
#   mean: -0.64828, std: 0.00533, params: {'min_samples_split': 600, 'max_depth': 1},
#   mean: -0.64909, std: 0.00572, params: {'min_samples_split': 800, 'max_depth': 1},
#   mean: -0.65034, std: 0.00579, params: {'min_samples_split': 1000, 'max_depth': 1},
#   mean: -0.59702, std: 0.00607, params: {'min_samples_split': 200, 'max_depth': 3},
#   mean: -0.59712, std: 0.00651, params: {'min_samples_split': 400, 'max_depth': 3},
#   mean: -0.59684, std: 0.00528, params: {'min_samples_split': 600, 'max_depth': 3},
#   mean: -0.59749, std: 0.00635, params: {'min_samples_split': 800, 'max_depth': 3},
#   mean: -0.59727, std: 0.00539, params: {'min_samples_split': 1000, 'max_depth': 3},
#   mean: -0.57336, std: 0.00653, params: {'min_samples_split': 200, 'max_depth': 5},
#   mean: -0.57397, std: 0.00577, params: {'min_samples_split': 400, 'max_depth': 5},
#   mean: -0.57529, std: 0.00587, params: {'min_samples_split': 600, 'max_depth': 5},
#   mean: -0.57524, std: 0.00609, params: {'min_samples_split': 800, 'max_depth': 5},
#   mean: -0.57605, std: 0.00581, params: {'min_samples_split': 1000, 'max_depth': 5},
#   mean: -0.56237, std: 0.00585, params: {'min_samples_split': 200, 'max_depth': 7},
#   mean: -0.56324, std: 0.00658, params: {'min_samples_split': 400, 'max_depth': 7},
#   mean: -0.56475, std: 0.00551, params: {'min_samples_split': 600, 'max_depth': 7},
#   mean: -0.56513, std: 0.00563, params: {'min_samples_split': 800, 'max_depth': 7},
#   mean: -0.56565, std: 0.00553, params: {'min_samples_split': 1000, 'max_depth': 7},
#   mean: -0.55798, std: 0.00571, params: {'min_samples_split': 200, 'max_depth': 9},
#   mean: -0.55876, std: 0.00597, params: {'min_samples_split': 400, 'max_depth': 9},
#   mean: -0.55920, std: 0.00688, params: {'min_samples_split': 600, 'max_depth': 9},
#   mean: -0.56042, std: 0.00582, params: {'min_samples_split': 800, 'max_depth': 9},
#   mean: -0.56107, std: 0.00588, params: {'min_samples_split': 1000, 'max_depth': 9},
#   mean: -0.55674, std: 0.00487, params: {'min_samples_split': 200, 'max_depth': 11},
#   mean: -0.55612, std: 0.00605, params: {'min_samples_split': 400, 'max_depth': 11},
#   mean: -0.55722, std: 0.00631, params: {'min_samples_split': 600, 'max_depth': 11},
#   mean: -0.55776, std: 0.00601, params: {'min_samples_split': 800, 'max_depth': 11},
#   mean: -0.55931, std: 0.00639, params: {'min_samples_split': 1000, 'max_depth': 11},
#   mean: -0.55858, std: 0.00596, params: {'min_samples_split': 200, 'max_depth': 13},
#   mean: -0.55645, std: 0.00512, params: {'min_samples_split': 400, 'max_depth': 13},
#   mean: -0.55664, std: 0.00594, params: {'min_samples_split': 600, 'max_depth': 13},
#   mean: -0.55763, std: 0.00624, params: {'min_samples_split': 800, 'max_depth': 13},
#   mean: -0.55795, std: 0.00617, params: {'min_samples_split': 1000, 'max_depth': 13},
#   mean: -0.55994, std: 0.00501, params: {'min_samples_split': 200, 'max_depth': 15},
#   mean: -0.55694, std: 0.00624, params: {'min_samples_split': 400, 'max_depth': 15},
#   mean: -0.55682, std: 0.00656, params: {'min_samples_split': 600, 'max_depth': 15},
#   mean: -0.55696, std: 0.00649, params: {'min_samples_split': 800, 'max_depth': 15},
#   mean: -0.55798, std: 0.00686, params: {'min_samples_split': 1000, 'max_depth': 15}],
#  {'max_depth': 11, 'min_samples_split': 400},
#  -0.55612171530849219)

# %%
param_test3 = {'min_samples_split':range(1,400, 20), 'min_samples_leaf':range(30,71,10)}
gsearch3 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=80,max_depth=11,max_features='sqrt',subsample=0.8),\
                        param_grid = param_test3, scoring='log_loss',n_jobs=4,iid=False, cv=5)
gsearch3.fit(drace_df[feats_used],y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=11, max_features='sqrt', max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=80,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'min_samples_split': [1, 21, 41, 61, 81, 101, 121, 141, 161, 181, 201, 221, 241, 261, 281, 301, 321, 341, 361, 381], 'min_samples_leaf': [30, 40, 50, 60, 70]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='log_loss', verbose=0)

# %%
gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# ([mean: -0.55856, std: 0.00542, params: {'min_samples_split': 1, 'min_samples_leaf': 30},
#   mean: -0.55877, std: 0.00547, params: {'min_samples_split': 21, 'min_samples_leaf': 30},
#   mean: -0.55858, std: 0.00638, params: {'min_samples_split': 41, 'min_samples_leaf': 30},
#   mean: -0.55807, std: 0.00581, params: {'min_samples_split': 61, 'min_samples_leaf': 30},
#   mean: -0.55790, std: 0.00539, params: {'min_samples_split': 81, 'min_samples_leaf': 30},
#   mean: -0.55653, std: 0.00600, params: {'min_samples_split': 101, 'min_samples_leaf': 30},
#   mean: -0.55614, std: 0.00659, params: {'min_samples_split': 121, 'min_samples_leaf': 30},
#   mean: -0.55711, std: 0.00505, params: {'min_samples_split': 141, 'min_samples_leaf': 30},
#   mean: -0.55585, std: 0.00650, params: {'min_samples_split': 161, 'min_samples_leaf': 30},
#   mean: -0.55660, std: 0.00605, params: {'min_samples_split': 181, 'min_samples_leaf': 30},
#   mean: -0.55607, std: 0.00598, params: {'min_samples_split': 201, 'min_samples_leaf': 30},
#   mean: -0.55585, std: 0.00631, params: {'min_samples_split': 221, 'min_samples_leaf': 30},
#   mean: -0.55479, std: 0.00586, params: {'min_samples_split': 241, 'min_samples_leaf': 30},
#   mean: -0.55547, std: 0.00597, params: {'min_samples_split': 261, 'min_samples_leaf': 30},
#   mean: -0.55563, std: 0.00521, params: {'min_samples_split': 281, 'min_samples_leaf': 30},
#   mean: -0.55581, std: 0.00626, params: {'min_samples_split': 301, 'min_samples_leaf': 30},
#   mean: -0.55592, std: 0.00576, params: {'min_samples_split': 321, 'min_samples_leaf': 30},
#   mean: -0.55665, std: 0.00539, params: {'min_samples_split': 341, 'min_samples_leaf': 30},
#   mean: -0.55650, std: 0.00617, params: {'min_samples_split': 361, 'min_samples_leaf': 30},
#   mean: -0.55624, std: 0.00599, params: {'min_samples_split': 381, 'min_samples_leaf': 30},
#   mean: -0.55700, std: 0.00615, params: {'min_samples_split': 1, 'min_samples_leaf': 40},
#   mean: -0.55717, std: 0.00626, params: {'min_samples_split': 21, 'min_samples_leaf': 40},
#   mean: -0.55730, std: 0.00568, params: {'min_samples_split': 41, 'min_samples_leaf': 40},
#   mean: -0.55735, std: 0.00558, params: {'min_samples_split': 61, 'min_samples_leaf': 40},
#   mean: -0.55824, std: 0.00647, params: {'min_samples_split': 81, 'min_samples_leaf': 40},
#   mean: -0.55759, std: 0.00519, params: {'min_samples_split': 101, 'min_samples_leaf': 40},
#   mean: -0.55691, std: 0.00490, params: {'min_samples_split': 121, 'min_samples_leaf': 40},
#   mean: -0.55746, std: 0.00564, params: {'min_samples_split': 141, 'min_samples_leaf': 40},
#   mean: -0.55662, std: 0.00539, params: {'min_samples_split': 161, 'min_samples_leaf': 40},
#   mean: -0.55505, std: 0.00457, params: {'min_samples_split': 181, 'min_samples_leaf': 40},
#   mean: -0.55635, std: 0.00639, params: {'min_samples_split': 201, 'min_samples_leaf': 40},
#   mean: -0.55571, std: 0.00597, params: {'min_samples_split': 221, 'min_samples_leaf': 40},
#   mean: -0.55492, std: 0.00637, params: {'min_samples_split': 241, 'min_samples_leaf': 40},
#   mean: -0.55582, std: 0.00545, params: {'min_samples_split': 261, 'min_samples_leaf': 40},
#   mean: -0.55506, std: 0.00623, params: {'min_samples_split': 281, 'min_samples_leaf': 40},
#   mean: -0.55600, std: 0.00631, params: {'min_samples_split': 301, 'min_samples_leaf': 40},
#   mean: -0.55563, std: 0.00669, params: {'min_samples_split': 321, 'min_samples_leaf': 40},
#   mean: -0.55605, std: 0.00696, params: {'min_samples_split': 341, 'min_samples_leaf': 40},
#   mean: -0.55633, std: 0.00572, params: {'min_samples_split': 361, 'min_samples_leaf': 40},
#   mean: -0.55624, std: 0.00582, params: {'min_samples_split': 381, 'min_samples_leaf': 40},
#   mean: -0.55678, std: 0.00546, params: {'min_samples_split': 1, 'min_samples_leaf': 50},
#   mean: -0.55632, std: 0.00611, params: {'min_samples_split': 21, 'min_samples_leaf': 50},
#   mean: -0.55698, std: 0.00647, params: {'min_samples_split': 41, 'min_samples_leaf': 50},
#   mean: -0.55674, std: 0.00582, params: {'min_samples_split': 61, 'min_samples_leaf': 50},
#   mean: -0.55606, std: 0.00640, params: {'min_samples_split': 81, 'min_samples_leaf': 50},
#   mean: -0.55668, std: 0.00598, params: {'min_samples_split': 101, 'min_samples_leaf': 50},
#   mean: -0.55714, std: 0.00533, params: {'min_samples_split': 121, 'min_samples_leaf': 50},
#   mean: -0.55644, std: 0.00661, params: {'min_samples_split': 141, 'min_samples_leaf': 50},
#   mean: -0.55650, std: 0.00606, params: {'min_samples_split': 161, 'min_samples_leaf': 50},
#   mean: -0.55666, std: 0.00673, params: {'min_samples_split': 181, 'min_samples_leaf': 50},
#   mean: -0.55563, std: 0.00547, params: {'min_samples_split': 201, 'min_samples_leaf': 50},
#   mean: -0.55629, std: 0.00621, params: {'min_samples_split': 221, 'min_samples_leaf': 50},
#   mean: -0.55546, std: 0.00587, params: {'min_samples_split': 241, 'min_samples_leaf': 50},
#   mean: -0.55607, std: 0.00686, params: {'min_samples_split': 261, 'min_samples_leaf': 50},
#   mean: -0.55547, std: 0.00606, params: {'min_samples_split': 281, 'min_samples_leaf': 50},
#   mean: -0.55647, std: 0.00704, params: {'min_samples_split': 301, 'min_samples_leaf': 50},
#   mean: -0.55616, std: 0.00634, params: {'min_samples_split': 321, 'min_samples_leaf': 50},
#   mean: -0.55548, std: 0.00624, params: {'min_samples_split': 341, 'min_samples_leaf': 50},
#   mean: -0.55657, std: 0.00721, params: {'min_samples_split': 361, 'min_samples_leaf': 50},
#   mean: -0.55655, std: 0.00545, params: {'min_samples_split': 381, 'min_samples_leaf': 50},
#   mean: -0.55662, std: 0.00548, params: {'min_samples_split': 1, 'min_samples_leaf': 60},
#   mean: -0.55674, std: 0.00554, params: {'min_samples_split': 21, 'min_samples_leaf': 60},
#   mean: -0.55751, std: 0.00628, params: {'min_samples_split': 41, 'min_samples_leaf': 60},
#   mean: -0.55619, std: 0.00567, params: {'min_samples_split': 61, 'min_samples_leaf': 60},
#   mean: -0.55628, std: 0.00562, params: {'min_samples_split': 81, 'min_samples_leaf': 60},
#   mean: -0.55689, std: 0.00590, params: {'min_samples_split': 101, 'min_samples_leaf': 60},
#   mean: -0.55717, std: 0.00640, params: {'min_samples_split': 121, 'min_samples_leaf': 60},
#   mean: -0.55688, std: 0.00649, params: {'min_samples_split': 141, 'min_samples_leaf': 60},
#   mean: -0.55525, std: 0.00682, params: {'min_samples_split': 161, 'min_samples_leaf': 60},
#   mean: -0.55609, std: 0.00628, params: {'min_samples_split': 181, 'min_samples_leaf': 60},
#   mean: -0.55598, std: 0.00583, params: {'min_samples_split': 201, 'min_samples_leaf': 60},
#   mean: -0.55541, std: 0.00584, params: {'min_samples_split': 221, 'min_samples_leaf': 60},
#   mean: -0.55543, std: 0.00597, params: {'min_samples_split': 241, 'min_samples_leaf': 60},
#   mean: -0.55604, std: 0.00704, params: {'min_samples_split': 261, 'min_samples_leaf': 60},
#   mean: -0.55581, std: 0.00608, params: {'min_samples_split': 281, 'min_samples_leaf': 60},
#   mean: -0.55611, std: 0.00712, params: {'min_samples_split': 301, 'min_samples_leaf': 60},
#   mean: -0.55691, std: 0.00674, params: {'min_samples_split': 321, 'min_samples_leaf': 60},
#   mean: -0.55556, std: 0.00652, params: {'min_samples_split': 341, 'min_samples_leaf': 60},
#   mean: -0.55581, std: 0.00709, params: {'min_samples_split': 361, 'min_samples_leaf': 60},
#   mean: -0.55613, std: 0.00649, params: {'min_samples_split': 381, 'min_samples_leaf': 60},
#   mean: -0.55564, std: 0.00611, params: {'min_samples_split': 1, 'min_samples_leaf': 70},
#   mean: -0.55522, std: 0.00619, params: {'min_samples_split': 21, 'min_samples_leaf': 70},
#   mean: -0.55616, std: 0.00586, params: {'min_samples_split': 41, 'min_samples_leaf': 70},
#   mean: -0.55678, std: 0.00614, params: {'min_samples_split': 61, 'min_samples_leaf': 70},
#   mean: -0.55589, std: 0.00627, params: {'min_samples_split': 81, 'min_samples_leaf': 70},
#   mean: -0.55575, std: 0.00640, params: {'min_samples_split': 101, 'min_samples_leaf': 70},
#   mean: -0.55649, std: 0.00576, params: {'min_samples_split': 121, 'min_samples_leaf': 70},
#   mean: -0.55590, std: 0.00621, params: {'min_samples_split': 141, 'min_samples_leaf': 70},
#   mean: -0.55537, std: 0.00674, params: {'min_samples_split': 161, 'min_samples_leaf': 70},
#   mean: -0.55634, std: 0.00613, params: {'min_samples_split': 181, 'min_samples_leaf': 70},
#   mean: -0.55599, std: 0.00663, params: {'min_samples_split': 201, 'min_samples_leaf': 70},
#   mean: -0.55656, std: 0.00600, params: {'min_samples_split': 221, 'min_samples_leaf': 70},
#   mean: -0.55714, std: 0.00555, params: {'min_samples_split': 241, 'min_samples_leaf': 70},
#   mean: -0.55648, std: 0.00595, params: {'min_samples_split': 261, 'min_samples_leaf': 70},
#   mean: -0.55553, std: 0.00692, params: {'min_samples_split': 281, 'min_samples_leaf': 70},
#   mean: -0.55658, std: 0.00682, params: {'min_samples_split': 301, 'min_samples_leaf': 70},
#   mean: -0.55593, std: 0.00526, params: {'min_samples_split': 321, 'min_samples_leaf': 70},
#   mean: -0.55643, std: 0.00663, params: {'min_samples_split': 341, 'min_samples_leaf': 70},
#   mean: -0.55589, std: 0.00687, params: {'min_samples_split': 361, 'min_samples_leaf': 70},
#   mean: -0.55635, std: 0.00549, params: {'min_samples_split': 381, 'min_samples_leaf': 70}],
#  {'min_samples_leaf': 30, 'min_samples_split': 241},
#  -0.55479367940651791)

# %%
param_test4 = {'subsample':[0.6,0.7,0.75,0.8,0.85,0.9]}
gsearch4 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=80,min_samples_leaf=30,max_depth=11,min_samples_split=241, max_features='sqrt'),\
                        param_grid = param_test4, scoring='log_loss',n_jobs=4,iid=False, cv=5)
gsearch4.fit(drace_df[feats_used],y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=11, max_features='sqrt', max_leaf_nodes=None,
#               min_samples_leaf=30, min_samples_split=241,
#               min_weight_fraction_leaf=0.0, n_estimators=80,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='log_loss', verbose=0)

# %%
gsearch4.grid_scores_, gsearch4.best_params_, gsearch4.best_score_
# Out:
# ([mean: -0.55706, std: 0.00563, params: {'subsample': 0.6},
#   mean: -0.55737, std: 0.00589, params: {'subsample': 0.7},
#   mean: -0.55645, std: 0.00657, params: {'subsample': 0.75},
#   mean: -0.55563, std: 0.00556, params: {'subsample': 0.8},
#   mean: -0.55538, std: 0.00564, params: {'subsample': 0.85},
#   mean: -0.55505, std: 0.00604, params: {'subsample': 0.9}],
#  {'subsample': 0.9},
#  -0.55505476573394408)

# %%
x = drace_df[feats_used]
y = drace_df["interest_level"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
gbmtuned = GradientBoostingClassifier(n_estimators=80, max_features='sqrt', subsample=0.9, min_samples_leaf=30, min_samples_split=241, max_depth=11)
gbmtuned.fit(x_train,y_train)
y_pred2 = gbmtuned.predict_proba(x_test[feats_used])
log_loss(y_test, y_pred2)
# Out:
# 0.57028467805476357

# %%
#something really wrong here ... I'll have to check when not so tired.

# %%
pd.Series(index = feats_used, data = gbmtuned.feature_importances_).sort_values().plot(kind = 'bar')

# %%
df_test.created = pd.to_datetime(df_test.created)
basic_numeric_features(df_test)
num_keyword(df_test)
n_log_price(df_test)
count_caps(df_test)
dist_from_midtown(df_test)
dist_to_nearest_college(df_test)
#
#        dist_to_nearest_college
# 0                  1306.027363
# 1                   350.804941
# 10                  390.958838
# 100                5214.209434
# 1000               1681.621002
# 10000              1294.709701
# 10001              6606.834716
# 10002              1033.918598
# 10003              7279.518183
# 10004               878.271177
# 10005              1013.477918
# 10006               817.480480
# 10007               837.635649
# 10008              2822.169927
# 10009               931.075100
# 1001                631.687848
# 10010              1531.055737
# 10011             12566.437953
# 10012               866.036112
# 10013              1274.912440
# 10014               510.500947
# 10015              2572.952029
# 10016              4756.514799
# 10017              1339.596469
# 10018               632.912056
# 10019              1083.210995
# 1002               2881.151383
# 10020               566.891828
# 10021               662.125463
# 10022              1191.949684
# ...                        ...
# 9972                315.279060
# 9973                442.801047
# 9974                532.968817
# 9975               1162.337369
# 9976                408.607415
# 9977               1191.949684
# 9978                675.642233
# 9979               1538.364159
# 998                 979.902244
# 9980               1318.823597
# 9981                364.721521
# 9982               8846.678625
# 9983               1143.133065
# 9984                579.254672
# 9985               6653.723821
# 9986                616.616835
# 9987               1257.156284
# 9988               2794.436944
# 9989                319.311773
# 999                 667.628451
# 9990                620.273492
# 9991               3887.658349
# 9992               1074.290236
# 9993               7871.134591
# 9994                425.018195
# 9995               1559.800080
# 9996                764.929967
# 9997                836.577051
# 9998               3772.644745
# 9999               1543.984056
#
# [74659 rows x 41 columns]

# %%
drace_df_test = df_test.reset_index().merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id').set_index('index')
new_manager_ixes = drace_df_test['high_frac'].isnull()
drace_df_test.loc[new_manager_ixes,['high_frac','low_frac', 'medium_frac','manager_skill']] = mean_values.values

# %%
drace_df_test = df_test.merge(temp, how='left', left_on='manager_id', right_index=True)
# drace_df_test.reset_index(df_test.index)
drace_df_test.head()
# Out:
#       0_per_72  100_per_72  10_per_72  20_per_72  30_per_72  40_per_72  \
# 0         2190        3937     2200.5     2350.0     2375.0     2397.0
# 1         2695        7000     2850.0     2875.0     3500.0     3550.0
# 10        1244        6500     3125.0     3914.0     4122.5     4295.0
# 100       1750        3500     2100.0     2250.0     2393.0     2475.0
# 1000      1700        4000     1700.0     1855.0     1893.0     2300.0
#
#       50_per_72  60_per_72  70_per_72  80_per_72      ...        \
# 0        2495.0     2650.0     2700.0     2840.0      ...
# 1        3650.0     3760.0     3950.0     4000.0      ...
# 10       4325.0     4717.0     4997.0     5680.0      ...
# 100      2500.0     2607.8     2739.9     2899.0      ...
# 1000     2383.0     2571.2     2700.0     2800.0      ...
#
#       n_num_keyfeat_score  n_log_price  amount_of_caps distance_from_midtown  \
# 0                       0     7.989560        0.080435           4458.895341
# 1                       0     7.955074        0.076923           3683.837201
# 10                      0     8.476371        0.000000           3023.823599
# 100                     0     7.740664        0.072289          10394.474638
# 1000                    0     7.919356        0.037135           3520.732330
#
#      dist_to_nearest_college high_frac low_frac medium_frac  count  \
# 0                1306.027363       NaN      NaN         NaN    NaN
# 1                 350.804941       NaN      NaN         NaN    NaN
# 10                390.958838       NaN      NaN         NaN    NaN
# 100              5214.209434       NaN      NaN         NaN    NaN
# 1000             1681.621002       NaN      NaN         NaN    NaN
#
#       manager_skill
# 0               NaN
# 1               NaN
# 10              NaN
# 100             NaN
# 1000            NaN
#
# [5 rows x 46 columns]

# %%
#apply all features to check
regex_col0 = {"nofee":'no fee', "doorman": 'doorman', "fitness": 'fitness|swimming', "hardwood": "hardwood",\
             "dishwash": 'dishwasher', "preWar": 'prewar|pre-war', 'furnished': 'furnished', "laundry": 'laundry',\
            "allow_pets": 'cats|dogs'}
import re

def create_regex_col0(df,regex,colname):
    def find_regex(lis):
        text = ' '.join(lis)
        r = re.compile(regex,flags=re.IGNORECASE)
        matches = r.findall(text)
        return len(matches)
    df[colname] = df['features'].apply(find_regex)
    
for name, regex in regex_col0.items():
    create_regex_col0(drace_df_test,regex,name)

# %%
#apply some samples for desc, jake has updated version
regex_col = {"subway":'train|trains|subway|line', "luxurious": 'luxury', "quiet_nei": 'quiet', "available": "available (immediately|now)",\
             "space_desc": 'foot|feet', "buzzword": 'must see'}

def create_regex_col(df,regex,colname):
    def find_regex(text):
        r = re.compile(regex,flags=re.IGNORECASE)
        matches = r.findall(text)
        return len(matches)
    df[colname] = df['description'].apply(find_regex)

for name, regex in regex_col.items():
    create_regex_col(drace_df_test,regex,name)

# %%
has_phone(drace_df_test)
drace_df_test['is_studio'] = np.where(drace_df_test['bedrooms'] == 0, '1', '0')
# Out:
# C:\Users\Drace\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:77: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
new_manager_ixes = drace_df_test['high_frac'].isnull()
drace_df_test.loc[new_manager_ixes,['high_frac','low_frac', 'medium_frac','manager_skill']] = mean_values.values
feats_used = ['bathrooms', 'bedrooms', 'created_day', 'latitude', 'longitude', 'manager_skill', \
             'n_log_price', 'price_vs_median_72_new', 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
              'dist_to_nearest_college']
x_Test = drace_df_test[feats_used]
submissionRF = rf.predict_proba(x_Test)

# %%
feats_used = ['bathrooms', 'bedrooms', 'created_day', 'latitude', 'longitude', 'manager_skill', \
             'n_log_price', 'price_vs_median_72', 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
              'dist_to_nearest_college']
rf.predict_proba(x_test[feats_used])
# Out:
# array([[ 0.164     ,  0.43      ,  0.406     ],
#        [ 0.043     ,  0.748     ,  0.209     ],
#        [ 0.16391667,  0.48008333,  0.356     ],
#        ...,
#        [ 0.151     ,  0.4483    ,  0.4007    ],
#        [ 0.175     ,  0.487     ,  0.338     ],
#        [ 0.043     ,  0.723     ,  0.234     ]])

# %%
testing = pd.DataFrame(rf.predict_proba(x_test[feats_used]))
# Out:
#                  0            1            2
# count  9837.000000  9837.000000  9837.000000
# mean      0.104946     0.604499     0.290555
# std       0.077641     0.148017     0.086652
# min       0.014500     0.117000     0.073000
# 25%       0.049000     0.495000     0.224000
# 50%       0.086600     0.616400     0.292667
# 75%       0.132000     0.723000     0.366000
# max       0.622000     0.901000     0.617000

# %%
print testing[0].sum()
print testing[1].sum()
print testing[2].sum()
# Out:
# 1032.35259762
# 5946.45296786
# 2858.19443452

# %%
drace_df.interest_level.value_counts()
# Out:
# low       34119
# medium    11224
# high       3838
# Name: interest_level, dtype: int64

# %%
submissionRF = pd.DataFrame(submissionRF)

# %%
submissionRF.head()
# Out:
#         0       1       2
# 0  0.1100  0.5364  0.3536
# 1  0.0810  0.6360  0.2830
# 2  0.1400  0.5300  0.3300
# 3  0.0425  0.7790  0.1785
# 4  0.1010  0.5634  0.3356

# %%
submissionRF = pd.concat([drace_df_test.reset_index(drop=True), submissionRF], axis=1)

# %%
submission_rf = submissionRF[['listing_id',0,1, 2]]

# %%
submissionRF[['listing_id',0,1, 2]].head()
# Out:
#    listing_id       0       1       2
# 0     7142618  0.1100  0.5364  0.3536
# 1     7210040  0.0810  0.6360  0.2830
# 2     6832604  0.1400  0.5300  0.3300
# 3     6830595  0.0425  0.7790  0.1785
# 4     6843709  0.1010  0.5634  0.3356

# %%
submission_rf.rename(columns={0: 'high', 1: 'low', 2: 'medium'}, inplace=True)
submission_rf = submission_rf[['listing_id', 'high', 'medium', 'low']]
# Out:
# C:\Users\Drace\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.py:2754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
submission_rf.head()
# Out:
#    listing_id    high  medium     low
# 0     7142618  0.1100  0.3536  0.5364
# 1     7210040  0.0810  0.2830  0.6360
# 2     6832604  0.1400  0.3300  0.5300
# 3     6830595  0.0425  0.1785  0.7790
# 4     6843709  0.1010  0.3356  0.5634

# %%
submission_rf.to_csv('C:\\Users\\Drace\\Documents\\submissionRF.csv', index = False)

# %%
sample = pd.read_csv('C:\Users\Drace\Documents\Neuromancers-Kaggle-master\sample_submission.csv')

# %%
sample.columns
# Out:
# Index([u'listing_id', u'high', u'medium', u'low'], dtype='object')

# %%
submission_rf.columns
# Out:
# Index([u'listing_id', u'high', u'medium', u'low'], dtype='object')

# %%
feats_used = ['bathrooms', 'bedrooms', 'created_day', 'latitude', 'longitude',\
             'n_log_price', 'price_vs_median_72_new', 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
              'dist_to_nearest_college']

submissiongbm0 = pd.DataFrame(gbm0.predict_proba(x_Test[feats_used]))
submissiongbm0 = pd.concat([drace_df_test.reset_index(drop=True), submissiongbm0], axis=1)
submissiongbm0.rename(columns={0: 'high', 1: 'low', 2: 'medium'}, inplace=True)
submissiongbm0 = submissiongbm0[['listing_id', 'high', 'medium', 'low']]

# %%
drace_df_test.building_id
# Out:
# 0        79780be1514f645d7e6be99a3de696c5
# 1                                       0
# 10       22bb41b4c5d4f19e38abf1ce17a39f0c
# 100      4b3fd7fdce05b05752a749bcf60b2b12
# 1000                                    0
# 10000    f5e976ad1487c5cc3e198dc9fead77c3
# 10001    15d8135ac5030fb076812afce8d75998
# 10002    a433bb20f3f94e3f3e6700286e351638
# 10003    2d7f90bc635fac396bf72ddacd49480e
# 10004    eaea5041914df950dc56f7782a35e426
# 10005    e87f1236b102798c1fa104a372800444
# 10006                                   0
# 10007    6506b7aa2479c442ad05b4d59291d801
# 10008    8b6837c814f880f36e468ecb2ed8e15b
# 10009    8e3b8c607c3edcf3de131c24f0390179
# 1001                                    0
# 10010                                   0
# 10011    7722ccfdb0fb5343fb5d695d553cfe31
# 10012    508baf62cd9cc74dd4be6bb722d020f9
# 10013    7b6936e72a5933904e00f20792ddd9ac
# 10014    8fdd765caad2697a73973e1dd256d817
# 10015    23b8a469761dd5d2aace55a1afc7e625
# 10016                                   0
# 10017    5a922b81c28dd44b2ffadf603c90c0d5
# 10018                                   0
# 10019    8303c099effd327c015824badf138765
# 1002     feb1540c405a3c14517841524e5a67e1
# 10020    a01c99eb2cfdde327e1691e17d6696ba
# 10021    a83c7f19005ade1561e984524a3ebbc8
# 10022    af79d0d2ed3d31362185fed210e97cb3
#                        ...
# 9972     d9b4a13d6460ca00a0b479d162971684
# 9973     5443e4c4f6eef3e2b17e22f9f6d32165
# 9974     c238352b679c89c774b4dfd50cbb2a4b
# 9975     f44cdef56f5fb6adfea7d4296dca0006
# 9976     d16f875956b264d5920d8424631091d4
# 9977     af79d0d2ed3d31362185fed210e97cb3
# 9978     093f64f52a6e43ba5e8f12bec8200554
# 9979                                    0
# 998      1e2f4c2a63d422caad3889bd7dd5403d
# 9980     0a1c09f6319121b4e54e6da1b695ff47
# 9981     c66639d47316de04fa4884c2c78cb865
# 9982     ccc290ed64b485d6cf950be4359f54ac
# 9983     8e4f9e04fc4c13f457b290fc1618bafa
# 9984     6c55aa813945e9f78021e8056eee052d
# 9985                                    0
# 9986     4fcbafb8d6bf902c6e2c3b09163e9224
# 9987     750f265a50473ce6c515bfded25e24f5
# 9988     ebb1fe8e32b8565f057a20abc495a2b5
# 9989     7335f5c4ed1a06d9b9735e8be1ac96d7
# 999      4181b86856ab5bc215199d222793adfe
# 9990     642cc2c920512ffe2a74c28122f8b47f
# 9991     53c1e03662e4430f87c05f9e1fd52b48
# 9992                                    0
# 9993     8ea96c26f9694b5e181f314845cdad15
# 9994     9c926bb8e5354ae22f3ebaaa3d1ee282
# 9995     3a956bd42c50f06ac84cf072fc514f5f
# 9996     bb92918d972748d02dec5f14baadd793
# 9997     0f19d347fcd9cc147a91c360c8976d52
# 9998                                    0
# 9999     ced6c1dc5241c92d153d2945cb391342
# Name: building_id, dtype: object

# %%
submissiongbm0.to_csv('C:\\Users\\Drace\\Documents\\submissiongbm0.csv', index = False)

# %%
feats_used = ['bathrooms', 'manager_skill', 'bedrooms', 'created_day', 'latitude', 'longitude',\
             'n_log_price', 'price_vs_median_72_new', 'num_photos', 'num_features', 'num_description_words', 'weekday_created',\
             'created_hour', 'is_studio', 'n_num_keyfeat_score','amount_of_caps', 'distance_from_midtown', 'allow_pets',\
              'laundry', 'preWar','furnished','dishwash','hardwood','fitness','doorman','nofee', 'has_phone',\
                'dist_to_nearest_college']

submissiongbm1 = pd.DataFrame(gbm1.predict_proba(x_Test[feats_used]))
submissiongbm1 = pd.concat([drace_df_test.reset_index(drop=True), submissiongbm1], axis=1)
submissiongbm1.rename(columns={0: 'high', 1: 'low', 2: 'medium'}, inplace=True)
submissiongbm1 = submissiongbm1[['listing_id', 'high', 'medium', 'low']]

# %%
submissiongbm1.to_csv('C:\\Users\\Drace\\Documents\\submissiongbm1.csv', index = False)
